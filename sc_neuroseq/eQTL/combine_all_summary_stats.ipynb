# %%
folder_D52_NONE = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/"
folder_D52_ROT = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/"

# %%
file = paste0(folder_D52_NONE,"celltype_DA/results/top_qtl_results_all.txt")
df = read.csv(file, sep = "\t")
nrow(df)
df$global_corr_p_value = p.adjust(df$empirical_feature_p_value, method = "BH")
nrow(df[df$global_corr_p_value < 0.05,])
# Out:
# [1] 9710
# [1] 698

# %%
file = paste0(folder_D52_NONE,"pseudobulk/results/top_qtl_results_all.txt")
df = read.csv(file, sep = "\t")
nrow(df)
df$global_corr_p_value = p.adjust(df$empirical_feature_p_value, method = "BH")
nrow(df[df$global_corr_p_value < 0.05,])
# Out:
# [1] 8722
# [1] 1379

# %%
celltypes = c("DA","Sert","Epen1","Astro")
files_d52_none = paste0(folder_D52_NONE,"celltype_",celltypes,"/results/qtl_results_all.txt")
files_d52_rot = paste0(folder_D52_ROT,"celltype_",celltypes,"/results/qtl_results_all.txt")
files = c(files_d52_none, files_d52_rot)
files
# Out:
# [1] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_DA/results/qtl_results_all.txt"
# [2] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_Sert/results/qtl_results_all.txt"
# [3] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_Epen1/results/qtl_results_all.txt"
# [4] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_Astro/results/qtl_results_all.txt"
# [5] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_DA/results/qtl_results_all.txt"
# [6] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_Sert/results/qtl_results_all.txt"
# ...

# %%
genes = c()
for (file in files){
    df = read.csv(file, sep = "\t")
#     print(head(df,2))
    df$feature_id = as.character(df$feature_id)
    genes = unique(c(genes, df$feature_id))
}

# %%
genes_d52 = genes
length(genes_d52)
# Out:
# [1] 10360

# %%
# day52
df = data.frame(genes = genes)
head(df,2)
write.csv(df, "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/genes_expressed_in_at_least_one_condition_d52.csv", quote = F, row.names = F)
# Out:
#   genes
# 1 ENSG00000170889
# 2 ENSG00000170906

# %%
daniel_folder_eqtl = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/"

# %%
celltypes = c("DA","Sert","Epen1","Astro")
files_d30 = paste0(daniel_folder_eqtl,'pool1_13_noddd_D30.',celltypes,'.qtl_results_all.sorted.txt')
files = files_d30
files
# Out:
# [1] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/pool1_13_noddd_D30.DA.qtl_results_all.sorted.txt"
# [2] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/pool1_13_noddd_D30.Sert.qtl_results_all.sorted.txt"
# [3] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/pool1_13_noddd_D30.Epen1.qtl_results_all.sorted.txt"
# [4] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/pool1_13_noddd_D30.Astro.qtl_results_all.sorted.txt"

# %%
genes = c()
for (file in files){
    df = read.csv(file, sep = "\t")
#     print(head(df,2))
    df$feature_id = as.character(df$feature_id)
    genes = unique(c(genes, df$feature_id))
}

# %%
genes_d30 = genes
length(genes_d30)
# Out:
# [1] 10357

# %%
# day30
df = data.frame(genes = genes)
head(df,2)
write.csv(df, "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/genes_expressed_at_d30.csv")
# Out:
#   genes
# 1 ENSG00000131591
# 2 ENSG00000187608

# %%
celltypes = c("FPP","P_FPP")
files_d11 = paste0(daniel_folder_eqtl,'pool1_13_noddd_D11.',celltypes,'.qtl_results_all.sorted.txt')
files = files_d11
files
# Out:
# [1] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/pool1_13_noddd_D11.FPP.qtl_results_all.sorted.txt"
# [2] "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/eqtl_from_daniel/summary_stats/pool1_13_noddd_D11.P_FPP.qtl_results_all.sorted.txt"

# %%
genes = c()
for (file in files){
    df = read.csv(file, sep = "\t")
#     print(head(df,2))
    df$feature_id = as.character(df$feature_id)
    genes = unique(c(genes, df$feature_id))
}

# %%
length(genes)
# Out:
# [1] 10073

# %%
genes_d11 = genes
length(genes_d11)
# Out:
# [1] 10073

# %%
# day11
df = data.frame(genes = genes)
head(df,2)
write.csv(df, "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/genes_expressed_at_d11.csv")
# Out:
#   genes
# 1 ENSG00000187961
# 2 ENSG00000188290

# %%
# df = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/genes_expressed_in_at_least_one_condition_d52.csv")
# head(df,2)
# genes_d52 = df$genes
# Out:
#   genes
# 1 ENSG00000170889
# 2 ENSG00000170906

# %%
all_genes = unique(c(genes_d11, genes_d30, genes_d52))
length(all_genes)
# Out:
# [1] 10549

# %%
# DA_NONE[DA_NONE$feature_id == 'ENSG00000044090',]

# %%
DA_NONE$global_corr_p_value = p.adjust(DA_NONE$empirical_feature_p_value, method = "BH")
DA_NONE = DA_NONE[DA_NONE$global_corr_p_value < 0.05,]
DA_NONE$label = "DA_D52"
colnames(DA_NONE)
# Out:
#  [1] "feature_id"                "snp_id"
#  [3] "p_value"                   "beta"
#  [5] "beta_se"                   "empirical_feature_p_value"
#  [7] "feature_chromosome"        "feature_start"
#  [9] "feature_end"               "n_samples"
# [11] "n_e_samples"               "alpha_param"
# [13] "beta_param"                "snp_chromosome"
# [15] "snp_position"              "assessed_allele"
# [17] "call_rate"                 "maf"
# [19] "hwe_p"                     "global_corr_p_value"
# [21] "label"

# %%
head(DA_NONE)
# Out:
#   feature_id      snp_id          p_value      beta       beta_se
# 1 ENSG00000170889 19_54701720_T_C 1.095786e-16 -0.3079343 0.03712773
# 2 ENSG00000170889 19_54717624_T_A 3.642230e-16 -0.3078378 0.03777197
# 3 ENSG00000170889 19_54718154_T_G 5.934515e-16 -0.3044865 0.03763435
# 4 ENSG00000170889 19_54700668_T_C 1.141540e-15 -0.2995843 0.03739851
# 5 ENSG00000170889 19_54701846_G_A 1.141540e-15 -0.2995843 0.03739851
# 6 ENSG00000170889 19_54701848_A_T 1.141540e-15 -0.2995843 0.03739851
#   empirical_feature_p_value feature_chromosome feature_start feature_end
# 1 1.507390e-08              19                 54704610      54752862
# 2 3.027767e-08              19                 54704610      54752862
# 3 4.020063e-08              19                 54704610      54752862
# 4 5.877626e-08              19                 54704610      54752862
# 5 5.877626e-08              19                 54704610      54752862
# ...

# %%
nrow(leads5pct)
leads = rbind(leads5pct,DA_NONE)
nrow(leads)
# Out:
# [1] 6046
# [1] 6744

# %%
# leads

# %%
Sert_NONE_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_Sert/results/top_qtl_results_all.txt"
Sert_NONE = read.csv(Sert_NONE_file,sep="\t")

# %%
Sert_NONE[Sert_NONE$feature_id == 'ENSG00000113645',]
# Out:
#      snp_id          p_value      beta      beta_se
# 7185 5_167746753_C_G 0.0007542683 0.2481389 0.07365241
#      empirical_feature_p_value feature_chromosome feature_start feature_end
# 7185 0.4572741                 5                  167718656     167899308
#      n_samples n_e_samples alpha_param beta_param snp_chromosome snp_position
# 7185 140       140         0.468639    214.765    5              167746753
#      assessed_allele call_rate maf       hwe_p     feature_id
# 7185 G               1         0.1821429 0.2504831 ENSG00000113645

# %%
Sert_NONE$global_corr_p_value = p.adjust(Sert_NONE$empirical_feature_p_value, method = "BH")
Sert_NONE = Sert_NONE[Sert_NONE$global_corr_p_value < 0.05,]
Sert_NONE$label = "Sert_D52"
colnames(Sert_NONE)
# Out:
#  [1] "snp_id"                    "p_value"
#  [3] "beta"                      "beta_se"
#  [5] "empirical_feature_p_value" "feature_chromosome"
#  [7] "feature_start"             "feature_end"
#  [9] "n_samples"                 "n_e_samples"
# [11] "alpha_param"               "beta_param"
# [13] "snp_chromosome"            "snp_position"
# [15] "assessed_allele"           "call_rate"
# [17] "maf"                       "hwe_p"
# [19] "feature_id"                "global_corr_p_value"
# [21] "label"

# %%
nrow(leads)
leads = rbind(leads,Sert_NONE)
nrow(leads)
# Out:
# [1] 6744
# [1] 7522

# %%
# leads

# %%
Epen1_NONE_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_Epen1/results/top_qtl_results_all.txt"
Epen1_NONE = read.csv(Epen1_NONE_file,sep="\t")
Epen1_NONE$global_corr_p_value = p.adjust(Epen1_NONE$empirical_feature_p_value, method = "BH")
Epen1_NONE = Epen1_NONE[Epen1_NONE$global_corr_p_value < 0.05,]
Epen1_NONE$label = "Epen1_D52"

# %%
nrow(leads)
leads = rbind(leads,Epen1_NONE)
nrow(leads)
# Out:
# [1] 7522
# [1] 8267

# %%
Astro_NONE_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_Astro/results/top_qtl_results_all.txt"
Astro_NONE = read.csv(Astro_NONE_file,sep="\t")
Astro_NONE$global_corr_p_value = p.adjust(Astro_NONE$empirical_feature_p_value, method = "BH")
Astro_NONE = Astro_NONE[Astro_NONE$global_corr_p_value < 0.05,]
Astro_NONE$label = "Astro_D52"

# %%
nrow(leads)
leads = rbind(leads,Astro_NONE)
nrow(leads)
# Out:
# [1] 8267
# [1] 8378

# %%
# leads

# %%
DA_ROT_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_DA/results/top_qtl_results_all.txt"
DA_ROT = read.csv(DA_ROT_file,sep="\t")
DA_ROT$global_corr_p_value = p.adjust(DA_ROT$empirical_feature_p_value, method = "BH")
DA_ROT = DA_ROT[DA_ROT$global_corr_p_value < 0.05,]
DA_ROT$label = "DA_ROT_D52"

# %%
nrow(leads)
leads = rbind(leads,DA_ROT)
nrow(leads)
# Out:
# [1] 8378
# [1] 8682

# %%
Sert_ROT_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_Sert/results/qtl_results_all.txt"
Sert_ROT = read.csv(Sert_ROT_file,sep="\t")
# Sert_ROT$global_corr_p_value = p.adjust(Sert_ROT$empirical_feature_p_value, method = "BH")
colnames(Sert_ROT)

# %%
### annotation file (map genes IDs)
annos_file = "/hps/nobackup/hipsci/scratch/singlecell_endodiff/data_processed/scQTLs/annos/combined_feature_id_annos.tsv"
annos = read.csv(annos_file,sep="\t")
# head(annos,2)
annos$feature_id = annos$ensembl_gene_id
head(annos,2)
# Out:
#   feature_id      chromosome start    end      hgnc_symbol
# 1 ENSG00000000003 X          99883667 99894988 TSPAN6
# 2 ENSG00000000419 20         49551404 49575092 DPM1
#   combined_feature_id    ensembl_gene_id
# 1 ENSG00000000003_TSPAN6 ENSG00000000003
# 2 ENSG00000000419_DPM1   ENSG00000000419

# %%
leads = Sert_ROT
for (i in 1:nrow(leads)){
    leads$gene_name[i] = as.character(annos[annos$feature_id == as.character(leads$feature_id[i]),"hgnc_symbol"])
}
head(leads,2)
Sert_ROT = leads

# %%
Sert_ROT[Sert_ROT$gene_name == 'SFXN5',]

# %%
-log10(Sert_ROT[Sert_ROT$gene_name == 'SFXN5','p_value'])

# %%
ENSG00000144040	2_73767897_G_A	1.0459092541009358e-05

# %%
Sert_ROT[Sert_ROT$feature_id == 'ENSG00000144040',]

# %%
Sert_ROT = Sert_ROT[Sert_ROT$global_corr_p_value < 0.05,]
Sert_ROT$label = "Sert_ROT_D52"

# %%
nrow(leads)
leads = rbind(leads,Sert_ROT)
nrow(leads)
# Out:
# [1] 8682
# [1] 9293

# %%
Epen1_ROT_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_Epen1/results/top_qtl_results_all.txt"
Epen1_ROT = read.csv(Epen1_ROT_file,sep="\t")
Epen1_ROT$global_corr_p_value = p.adjust(Epen1_ROT$empirical_feature_p_value, method = "BH")
Epen1_ROT = Epen1_ROT[Epen1_ROT$global_corr_p_value < 0.05,]
Epen1_ROT$label = "Epen1_ROT_D52"

# %%
nrow(leads)
leads = rbind(leads,Epen1_ROT)
nrow(leads)
# Out:
# [1] 9293
# [1] 9868

# %%
Astro_ROT_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_Astro/results/top_qtl_results_all.txt"
Astro_ROT = read.csv(Astro_ROT_file,sep="\t")
Astro_ROT$global_corr_p_value = p.adjust(Astro_ROT$empirical_feature_p_value, method = "BH")
Astro_ROT = Astro_ROT[Astro_ROT$global_corr_p_value < 0.05,]
Astro_ROT$label = "Astro_ROT_D52"

# %%
nrow(leads)
leads = rbind(leads,Astro_ROT)
nrow(leads)
# Out:
# [1] 9868
# [1] 9956

# %%
# leads

# %%
write.csv(leads,"/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_leads_5pct_FDR.csv", row.names = F, quote = F)

# %%
fvf_filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/feature_variant_filter.tsv"

# %%
leads = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_leads_5pct_FDR.csv")
head(leads,2)
# Out:
#   snp_id          p_value      beta       beta_se    empirical_feature_p_value
# 1 21_30373541_T_C 2.920966e-25 -0.8525780 0.08210206 1.632719e-14
# 2 21_30432557_G_A 1.495486e-48  0.5058675 0.03454695 1.169470e-31
#   feature_chromosome feature_start feature_end n_samples n_e_samples ...
# 1 21                 30376705      30391699    173       173         ...
# 2 21                 30428126      30446118    173       173         ...
#   snp_chromosome snp_position assessed_allele call_rate maf       hwe_p
# 1 21             30373541     C               1         0.2398844 0.09609073
# 2 21             30432557     A               1         0.1358382 1.00000000
#   feature_id      global_corr_p_value label   new_label
# 1 ENSG00000156253 1.400559e-12        FPP_D11 FPP_D11
# 2 ENSG00000156261 1.059433e-28        FPP_D11 FPP_D11

# %%
leads$label = as.character(leads$label)
leads$new_label = leads$label 
leads$new_label[leads$label == 'Astro_D30'] <- 'FPP_D30'

# %%
unique(leads$new_label)
# Out:
#  [1] "FPP_D11"       "P_FPP_D11"     "DA_D30"        "Sert_D30"
#  [5] "Epen1_D30"     "FPP_D30"       "DA_D52"        "Sert_D52"
#  [9] "Epen1_D52"     "Astro_D52"     "DA_ROT_D52"    "Sert_ROT_D52"
# [13] "Epen1_ROT_D52" "Astro_ROT_D52"

# %%
write.csv(leads,"/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_leads_5pct_FDR.csv")

# %%
nrow(leads)
leads$eqtl = paste0(leads$snp_id,"-",leads$feature_id)
length(unique(leads$eqtl))
# Out:
# [1] 9956
# [1] 7030

# %%
# fvf_df = leads
# fvf_df = fvf_df[-which(duplicated(fvf_df$eqtl)),]
# nrow(fvf_df)

# %%
# fvf_df = fvf_df[,c('snp_id','feature_id')]
# colnames(fvf_df)[2] = 'feature'
# head(fvf_df)
# write.table(fvf_df, fvf_filename, sep = "\t", col.names = T, row.names = F, quote = F)

# %%
head(leads,2)
# Out:
#   snp_id          p_value      beta       beta_se    empirical_feature_p_value
# 1 21_30373541_T_C 2.920966e-25 -0.8525780 0.08210206 1.632719e-14
# 2 21_30432557_G_A 1.495486e-48  0.5058675 0.03454695 1.169470e-31
#   feature_chromosome feature_start feature_end n_samples n_e_samples ...
# 1 21                 30376705      30391699    173       173         ...
# 2 21                 30428126      30446118    173       173         ...
#   snp_position assessed_allele call_rate maf       hwe_p      feature_id
# 1 30373541     C               1         0.2398844 0.09609073 ENSG00000156253
# 2 30432557     A               1         0.1358382 1.00000000 ENSG00000156261
#   global_corr_p_value label   new_label eqtl
# 1 1.400559e-12        FPP_D11 FPP_D11   21_30373541_T_C-ENSG00000156253
# 2 1.059433e-28        FPP_D11 FPP_D11   21_30432557_G_A-ENSG00000156261

# %%
leads$eqtl = paste0(leads$snp_id,"-",leads$feature_id)

# %%
# leads

# %%
# FPP & P_FPP
D11 = leads[leads$new_label == "FPP_D11",]
D30 = leads[leads$new_label == "FPP_D30",]
P_FPP = leads[leads$new_label == "P_FPP_D11",]

egenes0 = unique(D11$feature_id)
egenes1 = unique(D30$feature_id)
egenes2 = unique(P_FPP$feature_id)
##
D11 = c(length(egenes0),length(unique(c(egenes0,egenes1))),length(egenes2))
# D11 = c(length(egenes0),length(egenes2))

# %%
D11
# Out:
# [1] 1781 1799

# %%
# DA
D30 = leads[leads$label == "DA_D30",]
D52 = leads[leads$label == "DA_D52",]
D52_r = leads[leads$label == "DA_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
##
DA = c(length(egenes30),length(unique(c(egenes30,egenes))),length(unique(c(egenes30,egenes,egenesROT))))

# %%
DA

# %%
# Sert
D30 = leads[leads$label == "Sert_D30",]
D52 = leads[leads$label == "Sert_D52",]
D52_r = leads[leads$label == "Sert_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
##
Sert = c(length(egenes30),length(unique(c(egenes30,egenes))),length(unique(c(egenes30,egenes,egenesROT))))

# %%
Sert

# %%
# Epen1
D30 = leads[leads$label == "Epen1_D30",]
D52 = leads[leads$label == "Epen1_D52",]
D52_r = leads[leads$label == "Epen1_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
##
Epen1 = c(length(egenes30),length(unique(c(egenes30,egenes))),length(unique(c(egenes30,egenes,egenesROT))))

# %%
Epen1

# %%
# Astro
D52 = leads[leads$label == "Astro_D52",]
D52_r = leads[leads$label == "Astro_ROT_D52",]
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
##
Astro = c(length(egenes),length(unique(c(egenes,egenesROT))))

# %%
Astro

# %%
col_FPP = "#aec7e8"
col_P_FPP = "#1f77b4"
col_DA = "#2ca02c"
col_Sert = "#98df8a"
col_Epen1 = "#ff9896"
col_Astro = "#9467bd"

options(repr.plot.width = 5, repr.plot.height = 4)
my.xlim = c(0, 1800)
my.ylim = c(0,20)
my.space = c(0,0.1,0.3,0.5, 0.1, 0.1, 0.5, 0.1, 0.1, 0.5,0.1, 0.1,0.5,0.1)
opar <- par(lwd = 1)

barplot(c(D11,DA,Sert,Epen1,Astro),xlim = my.ylim, ylim = my.xlim, space = my.space,
       col = c(col_FPP,   col_FPP, col_P_FPP,
               col_DA,    col_DA,    col_DA, 
               col_Sert,  col_Sert,  col_Sert, 
               col_Epen1, col_Epen1, col_Epen1, 
               col_Astro, col_Astro))#,
#        border = c("lightgrey","darkgray","black", 
#                   "lightgrey","darkgray","black",  
#                   "lightgrey","darkgray","black", 
#                   "lightgrey","darkgray","black"))
# Out:
# plot without title

# %%
col_FPP = "#aec7e8"
col_P_FPP = "#1f77b4"
col_DA = "#2ca02c"
col_Sert = "#98df8a"
col_Epen1 = "#ff9896"
col_Astro = "#9467bd"

options(repr.plot.width = 5, repr.plot.height = 4)
my.xlim = c(0, 1800)
my.ylim = c(0,20)
my.space = c(0,0.3,0.5, 0.1, 0.1, 0.5, 0.1, 0.1, 0.5,0.1, 0.1,0.5,0.1)
opar <- par(lwd = 1)

barplot(c(D11,DA,Sert,Epen1,Astro),xlim = my.ylim, ylim = my.xlim, space = my.space,
       col = c(col_FPP,   col_P_FPP,
               col_DA,    col_DA,    col_DA, 
               col_Sert,  col_Sert,  col_Sert, 
               col_Epen1, col_Epen1, col_Epen1, 
               col_Astro, col_Astro))#,
#        border = c("lightgrey","darkgray","black", 
#                   "lightgrey","darkgray","black",  
#                   "lightgrey","darkgray","black", 
#                   "lightgrey","darkgray","black"))
# Out:
# plot without title

# %%
col_FPP = "#aec7e8"
col_P_FPP = "#1f77b4"
col_DA = "#2ca02c"
col_Sert = "#98df8a"
col_Epen1 = "#ff9896"
col_Astro = "#d62728"
col_Astro = "#9467bd"

options(repr.plot.width = 5, repr.plot.height = 4)
my.xlim = c(0, 1800)
my.ylim = c(0,20)
my.space = c(0,0.2,0.5, 0.1, 0.1, 0.5, 0.1, 0.1, 0.5,0.1, 0.1,0.5, 0.1,0.1)
opar <- par(lwd = 1)

barplot(c(D11,DA,Sert,Epen1,Astro),xlim = my.ylim, ylim = my.xlim, space = my.space,
       col = c(col_FPP,   col_P_FPP,
               col_DA,    col_DA,    col_DA, 
               col_Sert,  col_Sert,  col_Sert, 
               col_Epen1, col_Epen1, col_Epen1, 
               col_Astro, col_Astro, col_Astro))#,
#        border = c("lightgrey","darkgray","black", 
#                   "lightgrey","darkgray","black",  
#                   "lightgrey","darkgray","black", 
#                   "lightgrey","darkgray","black"))
# Out:
# plot without title

# %%
fit <- euler(c(D52 = 697-427-256, D30 = 672-427-221, D52_ROT = 303-256,
               "D52&D30" = 427-216,"D52&D52_ROT" = 256-216,"D30&D52_ROT" = 221-216,
               "D30&D52&D52_ROT" = 216))
plot(fit)
# Out:
# plot without title

# %%
# DA
D30 = leads[leads$label == "DA_D30",]
D52 = leads[leads$label == "DA_D52",]
D52_r = leads[leads$label == "DA_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
c(length(egenes),length(egenes[egenes %in% egenes30]),length(egenes[egenes %in% egenesROT]))
c(length(egenes30),length(egenes30[egenes30 %in% egenes]),length(egenes30[egenes30 %in% egenesROT]))
c(length(egenesROT),length(egenesROT[egenesROT %in% egenes]),length(egenesROT[egenesROT %in% egenes30]))
length(egenes[egenes %in% egenesROT & egenes %in% egenes30])

# %%
# Sert
D30 = leads[leads$label == "Sert_D30",]
D52 = leads[leads$label == "Sert_D52",]
D52_r = leads[leads$label == "Sert_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
c(length(egenes),length(egenes[egenes %in% egenes30]),length(egenes[egenes %in% egenesROT]))
c(length(egenes30),length(egenes30[egenes30 %in% egenes]))
c(length(egenesROT),length(egenesROT[egenesROT %in% egenes]))
# Out:
# [1] 777 403 461
# [1] 545 403
# [1] 610 461

# %%
# Epen1
D30 = leads[leads$label == "Epen1_D30",]
D52 = leads[leads$label == "Epen1_D52",]
D52_r = leads[leads$label == "Epen1_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
c(length(egenes),length(egenes[egenes %in% egenes30]),length(egenes[egenes %in% egenesROT]))
c(length(egenes30),length(egenes30[egenes30 %in% egenes]))
c(length(egenesROT),length(egenesROT[egenesROT %in% egenes]))
# Out:
# [1] 744 439 443
# [1] 621 439
# [1] 574 443

# %%
# Astro
D30 = leads[leads$label == "Astro_D30",]
D52 = leads[leads$label == "Astro_D52",]
D52_r = leads[leads$label == "Astro_ROT_D52",]
egenes30 = unique(D30$feature_id)
egenes = unique(D52$feature_id)
egenesROT = unique(D52_r$feature_id)
c(length(egenes),length(egenes[egenes %in% egenes30]),length(egenes[egenes %in% egenesROT]))
c(length(egenes30),length(egenes30[egenes30 %in% egenes]),length(egenes30[egenes30 %in% egenesROT]))
c(length(egenesROT),length(egenesROT[egenesROT %in% egenes]))
# Out:
# [1] 111 104  52
# [1] 617 104  78
# [1] 87 52

# %%
# install.packages("eulerr")
# library(eulerr)

fit <- euler(c(D52 = 7 , D30 = 503, D52_ROT = 87,"D52&D30" = 104,"D52&D52_ROT" = 52,"D30&D52_ROT" = 78))
plot(fit)
# Out:
# plot without title

# %%
install.packages("VennDiagram")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
# Load library
library(VennDiagram)

# %%
allgenes = unlist(unique(list(egenes,egenes30,egenesROT)))
head(allgenes)
# Out:
# [1] ENSG00000170889 ENSG00000134291 ENSG00000167550 ENSG00000152291
# [5] ENSG00000168894 ENSG00000057608
# 10398 Levels: ENSG00000001460 ENSG00000001629 ENSG00000002016 ... ENSG00000240184

# %%
d52 <- c(0)
for (i in 1:length(allgenes)){
    if (allgenes[i] %in% egenes){ d52[i] <- 1}
    else d52[i] <- 0
}

# %%
d30 <- c(0)
for (i in 1:length(allgenes)){
    if (allgenes[i] %in% egenes30){ d30[i] <- 1}
    else d30[i] <- 0
}

# %%
d52_r <- c(0)
for (i in 1:length(allgenes)){
    if (allgenes[i] %in% egenesROT){d52_r[i] <- 1}
    else d52_r[i] <- 0
}

# %%
# d30 <- (allgenes %in% egenes30)
# d52_r <- (allgenes %in% egenesROT)
c <- cbind(d52, d30, d52_r)

# %%
# c

# %%
library(limma)
a <- limma::vennCounts(c)

# %%
a
# Out:
#   d52 d30 d52_r Counts
# 1   0   0     0      0
# 2   0   0     1     42
# 3   0   1     0    240
# 4   0   1     1     10
# 5   1   0     0    230
# 6   1   0     1     80
# 7   1   1     0    422
# 8   1   1     1    648
# attr(,"class")
# [1] "VennCounts"

# %%
limma::vennDiagram(a)
# Out:
# plot without title

# %%
venn(x = a,
     zcolor = c(“blue, red, green”),
     size = 20, borders = FALSE,
     ellipse = TRUE,
     cexil = 1, cexsn = 1,
     opacity = 0.3)
# Out:
# Error in venn.default(x = a, opacity = 0.3): argument "combinations" is missing, with no default
# Traceback:
#
# 1. venn(x = a, opacity = 0.3)
# 2. venn.default(x = a, opacity = 0.3)

# %%
fit <- euler(c(D52 = 230, D30 = 240, D52_ROT = 42,
               "D52&D30" = 422,"D52&D52_ROT" = 80,"D30&D52_ROT" = 10,
               "D30&D52&D52_ROT" = 648))
plot(fit)
# Out:
# plot without title

# %%
# library(dplyr)
library(ggplot2)

# %%
res = inner_join(D30, D52, by = c("eqtl"), suffix = c(".D30",".D52"))
options(repr.plot.width = 5, repr.plot.height = 3.5)
ggplot(res, aes(x = -log10(p_value.D30), y = -log10(p_value.D52), col = beta.D30)) + 
    geom_point() #+ xlim(c(0,10)) + ylim(c(0,10)) + theme_minimal()
ggplot(res, aes(x = beta.D30, y = beta.D52, col = beta.D52)) + 
    geom_point() #+ xlim(c(0,10)) + ylim(c(0,10)) + theme_minimal()
# Out:
# plot without title
# plot without title

# %%
res = inner_join(D52_r, D52, by = c("eqtl"), suffix = c(".ROT",".NONE"))
head(res)
options(repr.plot.width = 5, repr.plot.height = 3.5)
ggplot(res, aes(x = -log10(p_value.ROT), y = -log10(p_value.NONE), col = beta.ROT)) + 
    geom_point() #+ xlim(c(0,10)) + ylim(c(0,10)) + theme_minimal()
ggplot(res, aes(x = beta.ROT, y = beta.NONE, col = beta.NONE)) + 
    geom_point() #+ xlim(c(0,10)) + ylim(c(0,10)) + theme_minimal()
# Out:
#   snp_id.ROT      p_value.ROT  beta.ROT   beta_se.ROT
# 1 10_5845061_A_G  4.329103e-08 -0.3363741 0.06141719
# 2 3_107763040_G_A 1.082419e-09  0.5030601 0.08251273
# 3 5_71496419_A_G  1.247651e-22 -0.5503044 0.05621306
# 4 5_70568209_G_A  7.924810e-17 -0.8674539 0.10410666
# 5 22_18888301_G_A 2.474534e-23 -1.2073278 0.12131651
# 6 1_39453785_G_A  8.822534e-10 -0.3630949 0.05923849
#   empirical_feature_p_value.ROT feature_chromosome.ROT feature_start.ROT
# 1 1.390016e-03                  10                       5807186
# 2 1.656952e-04                   3                     107762145
# 3 2.815299e-12                   5                      71403061
# 4 1.017484e-13                   5                      70330784
# 5 9.469238e-12                  22                      18893541
# 6 6.001705e-05                   1                      39491990
#   feature_end.ROT n_samples.ROT n_e_samples.ROT ⋯ beta_param.NONE
# 1   5884095       142           142             ⋯ 216.126158
# ...

# %%
DA_NONE_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_untreated/celltype_DA/results/top_qtl_results_all.txt"
DA_ROT_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_DA/results/qtl_results_all.txt"
D52 = read.csv(DA_NONE_file,sep="\t")
D52_r = read.csv(DA_ROT_file,sep="\t")

# %%
nrow(D52)
nrow(D52_r)
# Out:
# [1] 9710
# [1] 10511807

# %%
nrow(inner_join(D52,D52_r,by = c("snp_id","feature_id")))
# Out:
# Warning message:
# “Column `snp_id` joining factors with different levels, coercing to character vector”
# [1] 9429

# %%
res = inner_join(D52_r, D52, by = c("snp_id","feature_id"), suffix = c(".ROT",".NONE"))
nrow(res)
options(repr.plot.width = 6, repr.plot.height = 4.5)
ggplot(res, aes(x = -log10(p_value.ROT), y = -log10(p_value.NONE), col = beta.ROT)) + 
    geom_point() + xlim(c(0,90)) + ylim(c(0,90)) + theme_minimal()
ggplot(res, aes(x = beta.ROT, y = beta.NONE, col = beta.NONE)) + 
    geom_point() + xlim(c(-1.5,+1.5)) + ylim(c(-1.5,+1.5)) + theme_minimal()
ggplot(res, aes(x = -log10(p_value.ROT)*sign(beta.ROT), y = -log10(p_value.NONE)*sign(beta.NONE), col = beta.ROT)) + 
    geom_point() + xlim(c(-75,75)) + ylim(c(-75,75)) + theme_minimal()
# Out:
# Warning message:
# “Column `snp_id` joining factors with different levels, coercing to character vector”
# [1] 9429
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title
# plot without title

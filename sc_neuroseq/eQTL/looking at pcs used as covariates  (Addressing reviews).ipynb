# %%
mydir = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/timepoint_D52/input_files_ROT_treated/celltype_DA/"

# %%
pcs = read.csv(paste0(mydir, "covariates.tsv"),sep="\t")
head(pcs)
# Out:
#   index            PC1        PC2        PC3        PC4       PC5
# 1 HPSI0114i-bezi_3 -4.0453872 -3.5027092  1.7749864  1.950318 -2.0873059
# 2 HPSI0114i-eipl_1  5.2971628  4.4857823  1.8496031 -1.622522 -2.4346769
# 3 HPSI0114i-fikt_3  5.6506672 -1.3583694  3.7732791 -5.551446  9.4132671
# 4 HPSI0114i-kolf_2 -0.6786159 -5.0128938  0.6076810 -1.449867  0.4346458
# 5 HPSI0114i-lexy_2  1.9121103  0.8607209 -0.6344026  3.836240 -1.3051793
# 6 HPSI0114i-posc_1 -2.4974966 -1.1292973  1.4097881  2.928060 -2.9897032
#   PC6        PC7        PC8         PC9        PC10        PC11
# 1  0.2173530 -0.8886637  2.34081720  1.7517727 -2.45302302 -0.08680815
# 2 -2.5270890  0.0301752  0.01343532 -0.5269101 -0.71799425 -0.23823730
# 3  0.2823193 -3.3021485  2.41903408 -2.1767697  0.03930644 -0.61321197
# 4  0.5331306 -0.9568400 -2.27054828  0.7233043 -0.99618227  0.37427128
# 5  1.2676534 -2.6068471 -0.03865648 -0.1032177 -0.71867335 -0.67169552
# ...

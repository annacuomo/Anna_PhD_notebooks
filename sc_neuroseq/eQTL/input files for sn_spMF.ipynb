# %%
df_beta_sel = read.table("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_significant_eqtl_betas.tsv", header = TRUE)

# %%
head(df_beta_sel)
# Out:
#   Gene            SNP             FPP_D11      NB_D11       P_FPP_D11
# 1 ENSG00000162688 1_100301128_T_G  0.015603139  0.045106512 -0.01519113
# 2 ENSG00000188290 1_1003053_C_T   -0.126857444 -0.186214607 -0.20305646
# 3 ENSG00000162688 1_100326258_T_C  0.003695506 -0.032323893  0.02190326
# 4 ENSG00000137996 1_100765409_C_T -0.010414679  0.114434119 -0.11204631
# 5 ENSG00000130939 1_10232534_C_G   0.507148474 -0.070234095  0.43166690
# 6 ENSG00000142657 1_10442856_C_T   0.078364141  0.008685605  0.09439871
#   FPP_D30     DA_D30       Epen1_D30    Sert_D30      Astro_D52   DA_D52
# 1 -0.02009276 -0.030266430  0.005384307 -0.2585194460 -0.10942489 -0.27909368
# 2 -0.16386886  0.009662663 -0.290644390  0.0009150577 -0.03354175 -0.04439349
# 3  0.02128603  0.017405909 -0.003217216  0.2447660556  0.10942489  0.27909368
# 4 -0.02467420  0.027947212 -0.028948273 -0.0661169045  0.04349423 -0.14727438
# 5  0.03934685 -0.037736462 -0.130339622 -0.0123242021 -0.03735310 -0.11057747
# ...

# %%
df_beta_sel$summed_effect_size = 0
for (i in 1:nrow(df_beta_sel)){
    df_beta_sel$summed_effect_size[i] = sum(abs(df_beta_sel[i,3:ncol(df_beta_sel)]))
}

# %%
df_beta_sel = df_beta_sel[order(df_beta_sel$summed_effect_size, decreasing = TRUE),]
head(df_beta_sel)
# Out:
#      Gene            SNP             FPP_D11   NB_D11     P_FPP_D11  FPP_D30
# 4959 ENSG00000100376 22_45764874_T_C  1.653274  1.6709584  1.5583253  1.749332
# 4958 ENSG00000100376 22_45711854_G_A -1.653274 -1.6709584 -1.5583253 -1.749332
# 4095 ENSG00000183891 2_20090677_G_A   1.107169  0.8028999  1.2675506  1.522274
# 4096 ENSG00000183891 2_20106369_T_C   1.107169  0.8028999  1.2675506  1.522274
# 3116 ENSG00000132507 17_7207964_A_C  -1.102819 -1.1623038 -0.9406014 -1.250385
# 3115 ENSG00000132507 17_7207063_T_C  -1.084805 -1.1251196 -0.9083750 -1.245701
#      DA_D30    Epen1_D30 Sert_D30  Astro_D52 DA_D52    Epen1_D52 Sert_D52
# 4959  1.503144  1.842159  1.934683  1.891703  1.493865  1.945487  1.901075
# 4958 -1.503144 -1.842159 -1.934683 -1.891703 -1.493865 -1.945487 -1.901075
# 4095  1.589837  1.420510  1.566974  1.223984  1.705165  1.486548  1.743312
# 4096  1.589837  1.420510  1.566974  1.197837  1.653600  1.487122  1.640303
# ...

# %%
nrow(df_beta_sel)
df_beta_sel2 = df_beta_sel[-which(duplicated(df_beta_sel$Gene)),]
nrow(df_beta_sel2)
# Out:
# [1] 7514
# [1] 3470

# %%
length(unique(df_beta_sel2$Gene))
# Out:
# [1] 3470

# %%
df_beta_sel2$summed_effect_size = c()

# %%
head(df_beta_sel2)
# Out:
#      Gene            SNP             FPP_D11   NB_D11     P_FPP_D11  FPP_D30
# 4959 ENSG00000100376 22_45764874_T_C  1.653274  1.6709584  1.5583253  1.749332
# 4095 ENSG00000183891 2_20090677_G_A   1.107169  0.8028999  1.2675506  1.522274
# 3116 ENSG00000132507 17_7207964_A_C  -1.102819 -1.1623038 -0.9406014 -1.250385
# 4570 ENSG00000214078 20_34325470_G_A -1.528866 -1.0767502 -1.5816995 -1.112530
# 1659 ENSG00000197728 12_56401085_G_A -0.908467 -1.1839287 -1.0094294 -1.162931
# 1132 ENSG00000134809 11_57283988_C_T -1.179219 -1.0848658 -1.1237171 -1.345583
#      DA_D30     Epen1_D30 Sert_D30   Astro_D52 DA_D52     Epen1_D52 Sert_D52
# 4959  1.5031441  1.842159  1.9346825  1.891703  1.4938647  1.945487  1.9010747
# 4095  1.5898373  1.420510  1.5669737  1.223984  1.7051649  1.486548  1.7433115
# 3116 -1.1618386 -1.281332 -1.2464666 -1.195356 -1.2622505 -1.250989 -1.2494040
# 4570 -0.6306801 -1.307551 -0.9416711 -1.220882 -0.6285882 -1.402093 -1.5562358
# ...

# %%
genes1 = unique(df_beta_sel2$Gene)

# %%
write.table(df_beta_sel2[order(df_beta_sel2$Gene),], "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_significant_eqtl_top_snp_betas.tsv", sep = "\t",
           quote = FALSE, row.names = FALSE, col.names = TRUE)

# %%
### Standard errors

# %%
df_beta_sel_se = read.table("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_significant_eqtl_betas_se.tsv", header = TRUE)

# %%
df_beta_sel2$QTL = paste0(df_beta_sel2$SNP,"-",df_beta_sel2$Gene)
df_beta_sel_se$QTL = paste0(df_beta_sel_se$SNP,"-",df_beta_sel_se$Gene)

# %%
df_beta_sel2_se = df_beta_sel_se[df_beta_sel_se$QTL %in% df_beta_sel2$QTL,]

# %%
nrow(df_beta_sel2_se)
# Out:
# [1] 3470

# %%
genes2 = unique(df_beta_sel2_se$Gene)
length(genes2)
length(genes2[genes2 %in% genes1])
length(genes1[genes1 %in% genes2])
# Out:
# [1] 3470
# [1] 3470
# [1] 3470

# %%
df_beta_sel2$QTL = c()

# %%
tail(df_beta_sel2[order(df_beta_sel2$Gene),])
tail(df_beta_sel2_se[order(df_beta_sel2_se$Gene),])
# Out:
#      Gene            SNP             FPP_D11     NB_D11      P_FPP_D11
# 3343 ENSG00000267673 19_10391535_G_A -0.20296979  0.04440863 -0.1446394
# 3567 ENSG00000269190 19_39437508_G_A  0.55975670  0.05585650  0.6964077
# 3783 ENSG00000269343 19_58302271_A_G -0.03977925 -0.13397935 -0.1678331
# 6243 ENSG00000270800 6_34270668_C_T   0.61868628          NA  0.6201164
# 6174 ENSG00000272047 6_158631200_T_C -0.20418627 -0.10580554 -0.1750104
# 6250 ENSG00000272325 6_34406801_C_T  -0.49539075 -0.14034500 -0.1938963
#      FPP_D30     DA_D30       Epen1_D30   Sert_D30   Astro_D52  DA_D52
# 3343 -0.07580393  0.006717394 -0.03708913 -0.1020684 -0.1118316 -0.09241147
# 3567  0.17054616  0.066436289  0.30779676  0.1155369  0.1372241  0.33314909
# 3783 -0.09456432           NA -0.05878981 -0.1776502         NA          NA
# 6243          NA           NA          NA         NA         NA          NA
# 6174 -0.26354662 -0.312809136 -0.23622411 -0.3226764 -0.5706439 -0.62870595
# ...

# %%
write.table(df_beta_sel2_se[order(df_beta_sel2_se$Gene),], "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_significant_eqtl_top_snp_betas_se.tsv", sep = "\t",
           quote = FALSE, row.names = FALSE, col.names = TRUE)

# %%
nrow(df_beta_sel2_se)
# Out:
# [1] 3470

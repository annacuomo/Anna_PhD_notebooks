# %%
#################### full results eQTL files
data_folder = "/nfs/leia/research/stegle/dseaton/hipsci/singlecell_neuroseq/data/analysis_results/20200103_data_freeze/"
eqtl_folder = paste0(data_folder,"eqtl/summary_stats/")

# %%
### D52
# Dopaminergic neurons (DA)
DA.D52_filename = paste0(eqtl_folder,"pool1_17_D52.DA.qtl_results_all.sorted.txt.gz")
DA.D52 = read.table(gzfile(DA.D52_filename), header = TRUE)
# nrow(DA.D52)
head(DA.D52,2)
# Out:
#   feature_id      snp_id       p_value     beta      beta_se
# 1 ENSG00000131591 1_662622_G_A 0.002053446 0.3233397 0.10489897
# 2 ENSG00000187634 1_662622_G_A 0.194135506 0.1091702 0.08407787
#   empirical_feature_p_value feature_chromosome feature_start feature_end
# 1 -1                        1                  1017198       1051741
# 2 -1                        1                   860260        879955
#   n_samples n_e_samples snp_chromosome snp_position assessed_allele call_rate
# 1 179       179         1              662622       A               1
# 2 179       179         1              662622       A               1
#   maf        hwe_p
# 1 0.07541899 1
# 2 0.07541899 1

# %%
hist(DA.D52$beta)
hist(DA.D52$beta_se)
hist(DA.D52$beta/DA.D52$beta_se)
# Out:
# Plot with title “Histogram of DA.D52$beta”
# Plot with title “Histogram of DA.D52$beta_se”
# Plot with title “Histogram of DA.D52$beta/DA.D52$beta_se”

# %%
cols = c("feature_id","snp_id","beta","beta_se")

# %%
get_one_snp_per_gene <- function(res, cols){
    res = res[,cols]
    res$beta_se[res$beta_se == 0] <- 1e-15
    res$Z = res$beta/res$beta_se
    res = res[order(abs(res$Z), decreasing = T),]
    res = res[-which(duplicated(res$feature_id)),]
    res
}

# %%
DA.D52_egenes = get_one_snp_per_gene(DA.D52, cols)

# %%
head(DA.D52_egenes)
# Out:
#          feature_id      snp_id          beta      beta_se    Z
# 12381223 ENSG00000197728 12_56401085_G_A -1.173107 0.05660165 -20.72567
# 15969254 ENSG00000132507 17_7207964_A_C  -1.285759 0.06747385 -19.05567
# 9234013  ENSG00000086061 9_33026638_G_A  -1.102727 0.06288831 -17.53470
# 13154865 ENSG00000120675 13_43597706_C_T -1.269141 0.08006930 -15.85053
# 13778464 ENSG00000258289 14_65379283_A_G  1.248242 0.08051912  15.50243
# 16063479 ENSG00000214941 17_15875147_G_A -1.089043 0.07175150 -15.17798

# %%
options(repr.plot.width = 6, repr.plot.height = 3)
# hist(DA.D52_egenes$beta)
# hist(DA.D52_egenes$beta_se)
# hist(DA.D52_egenes$beta/DA.D52_egenes$beta_se)
hist(DA.D52_egenes$Z)
# Out:
# Plot with title “Histogram of DA.D52_egenes$Z”

# %%
# library(dplyr)

# %%
## D11
FPP.D11_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/FPP.D11.csv",row.names = 1)
P_FPP.D11_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/P_FPP.D11.csv", row.names = 1)
NB.D11_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/NB.D11.csv", row.names = 1)

# %%
hist(FPP.D11_egenes$beta)
hist(FPP.D11_egenes$beta_se)
hist(FPP.D11_egenes$Z)
# Out:
# Plot with title “Histogram of FPP.D11_egenes$beta”
# Plot with title “Histogram of FPP.D11_egenes$beta_se”
# Plot with title “Histogram of FPP.D11_egenes$Z”

# %%
## D30
DA.D30_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/DA.D30.csv", row.names = 1)
Sert.D30_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/Sert.D30.csv", row.names = 1)
Epen1.D30_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/Epen1.D30.csv", row.names = 1)
Astro.D30_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/Astro.D30.csv", row.names = 1)

# %%
## D52
DA.D52_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/DA.D52.csv", row.names = 1)
Sert.D52_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/Sert.D52.csv", row.names = 1)
Epen1.D52_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/Epen1.D52.csv", row.names = 1)
Astro.D52_egenes = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/eqtl/all_results_top_snp_per_gene/Astro.D52.csv", row.names = 1)

# %%
head(Sert.D52_egenes[order(Sert.D52_egenes$feature_id),])
# Out:
#          feature_id      snp_id          beta        beta_se    Z
# 19823725 ENSG00000000419 20_49238427_A_C -0.18801853 0.05071833 -3.707112
# 1425346  ENSG00000000457 1_170238415_G_A -0.12606051 0.03601767 -3.499963
# 1416861  ENSG00000000460 1_169730661_G_A -0.16091120 0.04570197 -3.520881
# 7241175  ENSG00000001036 6_143919974_G_A  0.21727382 0.05876763  3.697168
# 6894217  ENSG00000001084 6_53820434_T_C   0.08452801 0.02838008  2.978427
# 6775845  ENSG00000001167 6_41232277_T_A   0.11724862 0.04077571  2.875452

# %%
head(DA.D52_egenes[order(DA.D52_egenes$feature_id),])
# Out:
#          feature_id      snp_id          beta       beta_se    Z
# 19475323 ENSG00000000419 20_49226496_A_C  0.1558820 0.05024145  3.102658
# 1397671  ENSG00000000457 1_170110105_C_T -0.2789930 0.06679158 -4.177068
# 1398476  ENSG00000000460 1_170170202_C_T  0.2076016 0.06138224  3.382112
# 7105796  ENSG00000001036 6_143604514_G_A -0.1290555 0.04132563 -3.122893
# 6765338  ENSG00000001084 6_53438526_C_T  -0.2077643 0.06016558 -3.453209
# 6645618  ENSG00000001167 6_41239644_C_T  -0.1476869 0.03943707 -3.744874

# %%
# hist(Sert.D52_egenes$Z)

# %%
### given two sets of results, pick best snp per gene between the two based on its Z score 
get_top_snp_Z <- function(res1,res2){
    tmp = inner_join(res1,res2, by = "feature_id")
    for (i in 1:nrow(tmp)){
        if (abs(tmp$Z.x[i]) > abs(tmp$Z.y[i])){
            tmp$Z[i]   = tmp$Z.x[i]
            tmp$snp_id[i] = tmp$snp_id.x[i]
        }
        else {
            tmp$Z[i]   = tmp$Z.y[i]
            tmp$snp_id[i] = tmp$snp_id.y[i]
        }
    }
    tmp[,c("feature_id","snp_id","Z")]
}

# %%
r = get_top_snp_Z(DA.D52_egenes, Sert.D52_egenes)
head(r[order(r$feature_id),])
# Out:
#      feature_id      snp_id          Z
# 6739 ENSG00000000419 20_49238427_A_C -3.707112
# 1762 ENSG00000000457 1_170110105_C_T -4.177068
# 4970 ENSG00000000460 1_169730661_G_A -3.520881
# 6599 ENSG00000001036 6_143919974_G_A  3.697168
# 4562 ENSG00000001084 6_53438526_C_T  -3.453209
# 3089 ENSG00000001167 6_41239644_C_T  -3.744874

# %%
### given a list of sets of results, pick best snp per gene overall, iteratively 
get_top_snp_per_gene <- function(list_res){
    tmp = get_top_snp_Z(list_res[[1]],list_res[[2]])
    for (i in 3:length(list_res)){
        tmp = get_top_snp_Z(tmp, list_res[[i]])
    }
    tmp
}

# %%
head(Astro.D52_egenes[order(Astro.D52_egenes$feature_id),])
# Out:
#          feature_id      snp_id          beta       beta_se    Z
# 19388012 ENSG00000000419 20_49111256_T_G -0.1891188 0.05179173 -3.651526
# 1366450  ENSG00000000457 1_169523579_A_G -0.1621477 0.05319315 -3.048282
# 1365379  ENSG00000000460 1_169493726_G_C  0.1585200 0.04907209  3.230349
# 7098594  ENSG00000001036 6_143590630_G_A  0.3196416 0.09706881  3.292939
# 6765795  ENSG00000001084 6_53511224_T_C   0.2295167 0.06476478  3.543851
# 6648659  ENSG00000001167 6_40876663_A_G  -0.1499342 0.06795371 -2.206416

# %%
list_res = list(DA.D52_egenes, Sert.D52_egenes, Astro.D52_egenes)

# %%
r = get_top_snp_per_gene(list_res)
head(r[order(r$feature_id),])
# Out:
#      feature_id      snp_id          Z
# 6582 ENSG00000000419 20_49238427_A_C -3.707112
# 1720 ENSG00000000457 1_170110105_C_T -4.177068
# 4861 ENSG00000000460 1_169730661_G_A -3.520881
# 6443 ENSG00000001036 6_143919974_G_A  3.697168
# 4463 ENSG00000001084 6_53511224_T_C   3.543851
# 3016 ENSG00000001167 6_41239644_C_T  -3.744874

# %%
list_res = list(FPP.D11_egenes, P_FPP.D11_egenes, NB.D11_egenes,
               DA.D30_egenes, Sert.D30_egenes, Epen1.D30_egenes, Astro.D30_egenes,
               DA.D52_egenes, Sert.D52_egenes, Epen1.D52_egenes, Astro.D52_egenes)

# %%
## at the end of this we should have a list of the top snp (max Z across celltypes) for each gene
r = get_top_snp_per_gene(list_res)
head(r[order(r$feature_id),])
# Out:
#      feature_id      snp_id          Z
# 4451 ENSG00000000419 20_49238427_A_C -3.707112
# 8438 ENSG00000000457 1_170110105_C_T -4.177068
# 5925 ENSG00000000460 1_169523910_T_A  4.157174
# 6387 ENSG00000001036 6_143810682_A_T -4.848003
# 5581 ENSG00000001084 6_53494614_T_A  -4.265597
# 5711 ENSG00000001167 6_41239644_C_T  -3.744874

# %%
hist(r$Z)
# Out:
# Plot with title “Histogram of r$Z”

# %%
nrow(r)
length(unique(r$feature_id))
# Out:
# [1] 8748
# [1] 8748

# %%
head(r)
# Out:
#   feature_id      snp_id
# 1 ENSG00000134809 11_57283988_C_T
# 2 ENSG00000170291 17_7145981_T_C
# 3 ENSG00000124614 6_34397920_G_A
# 4 ENSG00000093072 22_17680519_A_C
# 5 ENSG00000240344 2_201754063_T_C
# 6 ENSG00000197728 12_56401085_G_A

# %%
# list_res = list(FPP.D11, P_FPP.D11, NB.D11,
#                DA.D30, Sert.D30, Epen1.D30, Astro.D30,
#                DA.D52, Sert.D52, Epen1.D52, Astro.D52)

# %%
### this should return Z scores for each cell type for the selected snp-gene pairs
r = r[,c("feature_id","snp_id")]
get_Zs_for_the_top_snp_per_gene <- function(r, list_res, res_names){
    for (i in 1:length(list_res)){
        celltype = res_names[i]
        res = list_res[[i]]
        r = inner_join(r, res, by = c("feature_id","snp_id"))
#         r = left_join(r, res, by = c("feature_id","snp_id"))
        r$beta_se[r$beta_se==0] = 1e-5
        r[[paste0("Z.",celltype)]] = r$beta/r$beta_se
        r = r[,c("snp_id","feature_id",colnames(r)[grep("Z",colnames(r))])]
    }
    r
}

# %%
# res_names = c("FPP.D11", "P_FPP.D11", "NB.D11",
#                "DA.D30", "Sert.D30", "Epen1.D30", "Astro.D30",
#                "DA.D52", "Sert.D52", "Epen1.D52", "Astro.D52")

# %%
# ## for the selected snp-gene pairs, Z score for each of our cell types
# # rank by ABSOLUTE value of Z
# r_all = get_Zs_for_the_top_snp_per_gene(r, list_res, res_names)
# head(r_all[order(abs(r_all$Z.FPP.D11)),])

# %%
# ru = r_all[order(abs(r_all$Z.FPP.D11), decreasing = T),]
# ru = ru[-which(duplicated(ru$feature_id)),]
# head(ru,2)
# nrow(ru)
# length(unique(ru$feature_id))

# %%
# save snps to parse GTEx
snps = as.data.frame(matrix(ru$snp_id, nrow = nrow(ru), ncol = 1))
colnames(snps) = "snp_id"
write.csv(snps, "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/top_snp_allgenes.csv")

# %%
ru = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/top_snp_allgenes_Zscores_celltypes.csv", row.names = 1)

# %%
head(ru)
# Out:
#   snp_id          feature_id      Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11 Z.DA.D30
# 1 17_7145981_T_C  ENSG00000170291 17.60191  19.06328    7.378654  1.520777
# 2 22_17680519_A_C ENSG00000093072 17.21335  16.47538    9.035217 11.335143
# 3 6_34313198_A_C  ENSG00000124614 17.12862  17.51080    9.608990 11.336262
# 4 14_50087357_C_G ENSG00000165502 15.91991  13.71375    7.136861  5.730349
# 5 22_42467695_G_C ENSG00000183172 15.81211  14.90647    8.896546  9.133496
# 6 7_135349273_A_T ENSG00000243317 15.77543  16.24964    8.922753  6.300905
#   Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52  Z.Sert.D52 Z.Epen1.D52
# 1 13.486731  11.883131   13.329171    3.992745 18.896421  15.128259
# 2 13.026680   8.723859   10.858490   11.971600 17.406373  15.563942
# 3 12.092161  12.618021   13.939369   12.109222 12.385210  15.595517
# 4  6.551487   4.718919    7.000421    5.247296  7.861135  10.051773
# 5  9.088928   5.368477    9.135831    8.121149 10.102117   8.764023
# 6  9.356267   5.671071    7.222986    9.411775 12.515125  12.204969
#   Z.Astro.D52
# 1 10.205351
# 2  9.950645
# 3 10.809285
# 4  5.740373
# 5  7.218523
# 6  9.420360

# %%
mat = ru[,-c(1,2)]
rownames(mat) <- paste0(ru$feature_id,"-",ru$snp_id)
head(mat)
# Out:
#                                 Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11 Z.DA.D30
# ENSG00000170291-17_7145981_T_C  17.60191  19.06328    7.378654  1.520777
# ENSG00000093072-22_17680519_A_C 17.21335  16.47538    9.035217 11.335143
# ENSG00000124614-6_34313198_A_C  17.12862  17.51080    9.608990 11.336262
# ENSG00000165502-14_50087357_C_G 15.91991  13.71375    7.136861  5.730349
# ENSG00000183172-22_42467695_G_C 15.81211  14.90647    8.896546  9.133496
# ENSG00000243317-7_135349273_A_T 15.77543  16.24964    8.922753  6.300905
#                                 Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52
# ENSG00000170291-17_7145981_T_C  13.486731  11.883131   13.329171    3.992745
# ENSG00000093072-22_17680519_A_C 13.026680   8.723859   10.858490   11.971600
# ENSG00000124614-6_34313198_A_C  12.092161  12.618021   13.939369   12.109222
# ENSG00000165502-14_50087357_C_G  6.551487   4.718919    7.000421    5.247296
# ENSG00000183172-22_42467695_G_C  9.088928   5.368477    9.135831    8.121149
# ENSG00000243317-7_135349273_A_T  9.356267   5.671071    7.222986    9.411775
#                                 Z.Sert.D52 Z.Epen1.D52 Z.Astro.D52
# ENSG00000170291-17_7145981_T_C  18.896421  15.128259   10.205351
# ENSG00000093072-22_17680519_A_C 17.406373  15.563942    9.950645
# ENSG00000124614-6_34313198_A_C  12.385210  15.595517   10.809285
# ENSG00000165502-14_50087357_C_G  7.861135  10.051773    5.740373
# ENSG00000183172-22_42467695_G_C 10.102117   8.764023    7.218523
# ENSG00000243317-7_135349273_A_T 12.515125  12.204969    9.420360

# %%
pca = prcomp(t(mat))
pcs = pca$x
head(pcs)

pca_df = as.data.frame(pcs)
# Out:
#             PC1        PC2       PC3         PC4       PC5       PC6
# Z.FPP.D11   -146.50120   5.28180 -17.5316912  10.38754 -1.744591   3.225130
# Z.P_FPP.D11 -156.90983   8.27864 -13.8173702  17.10066  6.613896   8.231497
# Z.NB.D11     -15.26801  13.05144 124.7583651 -71.33334 -5.011194 -53.063916
# Z.DA.D30      40.99856 -69.21512  36.6948831  65.30976  2.698713  -1.730481
# Z.Sert.D30    39.44493 -46.39116   7.5358711 -23.05255 64.218666  36.544069
# Z.Epen1.D30   58.41612  73.84593   0.5341382  25.71317 47.632120 -31.359718
#             PC7        PC8        PC9        PC10       PC11
# Z.FPP.D11     4.377372   3.605427  -6.928227  68.870418  8.770762e-15
# Z.P_FPP.D11  -4.473930   9.897178   5.387060 -64.206645 -1.715295e-13
# Z.NB.D11      5.146607 -19.777312   2.913325  -2.072263 -7.913115e-14
# Z.DA.D30     32.908677  17.777433  68.764606   4.886403  2.930989e-14
# Z.Sert.D30   55.035249  24.503576 -53.473133  -4.067322  8.937295e-15
# Z.Epen1.D30 -54.513236  59.517949  -4.004241   4.967315  1.069977e-13

# %%
library(ggplot2)

# %%
col_FPP = "#aec7e8"
col_P_FPP = "#1f77b4"
col_NB = "#ff7f0e"

col_DA = "#2ca02c"
col_Sert = "#98df8a"
col_Epen1 = "#ff9896"
col_Astro = "#d62728"

# %%
df = data.frame(celltype = gsub("-.*","",gsub("Z-","",gsub("\\.","-",rownames(pca_df)))), 
                                day = gsub(".*.D","D",rownames(pca_df)),
                                PC1 = pca_df$PC1, PC2 = pca_df$PC2)
head(df,2)

ggplot(df, aes(x = PC1, y = PC2, shape = day, colour = celltype)) + 
    geom_point(size = 3) +  scale_color_manual(values=c(col_Astro, col_DA, col_Epen1,
                                                col_FPP, col_NB, col_P_FPP, col_Sert)) + theme_minimal()
# Out:
#   celltype day PC1       PC2
# 1 FPP      D11 -146.5012 5.28180
# 2 P_FPP    D11 -156.9098 8.27864
# plot without title

# %%
matZ = pcs %*% t(pcs)
head(matZ)

# library(ComplexHeatmap)
# library(circlize)

m = min(matZ)
M = max(matZ)
options(repr.plot.width = 5.5, repr.plot.height = 4.5)
Heatmap(matZ, cluster_rows = F, cluster_columns = F, col = colorRamp2(c(m, M), c("white", "firebrick")), 
       name = "Z score \ncorrelations")
# Out:
#             Z.FPP.D11  Z.P_FPP.D11 Z.NB.D11   Z.DA.D30  Z.Sert.D30 Z.Epen1.D30
# Z.FPP.D11   26742.4995 19022.9266   -996.5606 -6278.863 -5969.898  -7748.691
# Z.P_FPP.D11 19022.9266 29553.5671   -979.8872 -6307.252 -6376.766  -7573.049
# Z.NB.D11     -996.5606  -979.8872  24327.8502 -1523.805 -1232.848  -1749.918
# Z.DA.D30    -6278.8630 -6307.2520  -1523.8053 18245.239  2259.010  -1821.504
# Z.Sert.D30  -5969.8981 -6376.7655  -1232.8484  2259.010 16260.980  -1145.279
# Z.Epen1.D30 -7748.6913 -7573.0489  -1749.9176 -1821.504 -1145.279  19334.155
#             Z.Astro.D30  Z.DA.D52   Z.Sert.D52 Z.Epen1.D52 Z.Astro.D52
# Z.FPP.D11   -5123.785039 -4862.4470 -3711.570  -5167.063   -5906.5481
# Z.P_FPP.D11 -4921.063420 -5601.2334 -4471.350  -6047.064   -6298.8289
# Z.NB.D11    -2352.218050 -3478.0868 -6204.673  -6483.147     673.2936
# Z.DA.D30       -2.474506  5098.5701 -2137.772  -4921.355   -2609.7932
# Z.Sert.D30     94.043724  -719.3998  2488.711  -3542.962   -2115.5910
# Z.Epen1.D30  3179.503722 -3755.6000 -3892.296   4544.018     628.6605
# Loading required package: grid
# ========================================
# ComplexHeatmap version 1.17.1
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://bioconductor.org/packages/ComplexHeatmap/
#
# If you use it in published research, please cite:
# Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#   genomic data. Bioinformatics 2016.
# ========================================
#
# ========================================
# circlize version 0.4.3
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: http://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
# ========================================
# plot without title

# %%
####### GTEx parsed (only our genes) files

# %%
gtex_folder = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/mean_eqtl/jan17/"
list.files(gtex_folder)
# Out:
#  [1] "Adipose_Subcutaneous.tsv"
#  [2] "Adipose_Visceral_Omentum.tsv"
#  [3] "Adrenal_Gland.tsv"
#  [4] "Artery_Aorta.tsv"
#  [5] "Artery_Coronary.tsv"
#  [6] "Artery_Tibial.tsv"
#  [7] "Brain_Amygdala.tsv"
#  [8] "Brain_Anterior_cingulate_cortex_BA24.tsv"
#  [9] "Brain_Caudate_basal_ganglia.tsv"
# [10] "Brain_Cerebellar_Hemisphere.tsv"
# [11] "Brain_Cerebellum.tsv"
# [12] "Brain_Cortex.tsv"
# [13] "Brain_Frontal_Cortex_BA9.tsv"
# [14] "Brain_Hippocampus.tsv"
# [15] "Brain_Hypothalamus.tsv"
# [16] "Brain_Nucleus_accumbens_basal_ganglia.tsv"
# [17] "Brain_Putamen_basal_ganglia.tsv"
# [18] "Brain_Spinal_cord_cervical_c-1.tsv"
# [19] "Brain_Substantia_nigra.tsv"
# [20] "Breast_Mammary_Tissue.tsv"
# [21] "Cells_EBV-transformed_lymphocytes.tsv"
# [22] "Cells_Transformed_fibroblasts.tsv"
# [23] "Colon_Sigmoid.tsv"
# [24] "Colon_Transverse.tsv"
# [25] "Esophagus_Gastroesophageal_Junction.tsv"
# [26] "Esophagus_Mucosa.tsv"
# [27] "Esophagus_Muscularis.tsv"
# [28] "Heart_Atrial_Appendage.tsv"
# [29] "Heart_Left_Ventricle.tsv"
# [30] "Liver.tsv"
# [31] "Lung.tsv"
# [32] "Minor_Salivary_Gland.tsv"
# [33] "Muscle_Skeletal.tsv"
# [34] "Nerve_Tibial.tsv"
# [35] "Ovary.tsv"
# [36] "Pancreas.tsv"
# [37] "Pituitary.tsv"
# [38] "Prostate.tsv"
# [39] "Skin_Not_Sun_Exposed_Suprapubic.tsv"
# [40] "Skin_Sun_Exposed_Lower_leg.tsv"
# [41] "Small_Intestine_Terminal_Ileum.tsv"
# [42] "Spleen.tsv"
# [43] "Stomach.tsv"
# [44] "Testis.tsv"
# [45] "Thyroid.tsv"
# [46] "Uterus.tsv"
# [47] "Vagina.tsv"
# [48] "Whole_Blood.tsv"

# %%
myfiles = list.files(gtex_folder)
myfilenames = gsub(".tsv","",myfiles)
head(myfilenames)
# Out:
# [1] "Adipose_Subcutaneous"     "Adipose_Visceral_Omentum"
# [3] "Adrenal_Gland"            "Artery_Aorta"
# [5] "Artery_Coronary"          "Artery_Tibial"

# %%
gtex_files = list()
for (i in 1:length(myfiles)){
# for (i in 1){
    mysuffix = myfiles[i]
#     mysuffix
    myfilename = paste0(gtex_folder, mysuffix)
    myfile = read.table(myfilename, row.names = 1)
#     print(head(myfile))
    colnames(myfile) <- c("feature_id","snp_id","p_value","beta","beta_se")
    # myfile$beta_se[myfile$beta_se==0] <- 1e-15
    # myfile$Z = myfile$beta/myfile$beta_se
    gtex_files[[i]] <- myfile
}

# %%
ru[ru$snp_id == "22_51208537_G_A",]
# Out:
#       snp_id          feature_id      Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11
# 42185 22_51208537_G_A ENSG00000196576 0.3198847 -2.101232   -0.5203946
#       Z.DA.D30   Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52 Z.Sert.D52
# 42185 -0.7646928 1.107766   -0.5542885  0.1139653   4.332362 1.634976
#       Z.Epen1.D52 Z.Astro.D52
# 42185 0.2175947   -0.2785934

# %%
nrow(gtex_files[[i]])
sum(gtex_files[[i]]$snp_id %in% ru$snp_id)
# Out:
# [1] 247996
# [1] 247996

# %%
i = 20
hist(gtex_files[[i]]$beta/gtex_files[[i]]$beta_se)
# Out:
# Plot with title “Histogram of gtex_files[[i]]$beta/gtex_files[[i]]$beta_se”

# %%
gtex_names = myfilenames
gtex_list = gtex_files
r_all_gtex = get_Zs_for_the_top_snp_per_gene(ru, gtex_list, gtex_names)

# %%
head(r_all_gtex )
# Out:
#   snp_id          feature_id      Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11 Z.DA.D30
# 1 17_7145981_T_C  ENSG00000170291 17.60191  19.06328    7.378654  1.520777
# 2 22_17680519_A_C ENSG00000093072 17.21335  16.47538    9.035217 11.335143
# 3 6_34313198_A_C  ENSG00000124614 17.12862  17.51080    9.608990 11.336262
# 4 14_50087357_C_G ENSG00000165502 15.91991  13.71375    7.136861  5.730349
# 5 22_42467695_G_C ENSG00000183172 15.81211  14.90647    8.896546  9.133496
# 6 7_135349273_A_T ENSG00000243317 15.77543  16.24964    8.922753  6.300905
#   Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52  ⋯
# 1 13.486731  11.883131   13.329171    3.992745 ⋯
# 2 13.026680   8.723859   10.858490   11.971600 ⋯
# 3 12.092161  12.618021   13.939369   12.109222 ⋯
# 4  6.551487   4.718919    7.000421    5.247296 ⋯
# 5  9.088928   5.368477    9.135831    8.121149 ⋯
# 6  9.356267   5.671071    7.222986    9.411775 ⋯
#   Z.Skin_Not_Sun_Exposed_Suprapubic Z.Skin_Sun_Exposed_Lower_leg
# 1  8.062412                         10.038159
# 2 18.796729                         25.027920
# 3  7.092391                          9.967281
# 4 21.149708                         20.454847
# 5 29.151845                         32.843181
# 6 16.895833                         16.667860
#   Z.Small_Intestine_Terminal_Ileum Z.Spleen   Z.Stomach Z.Testis  Z.Thyroid
# 1  1.144704                         0.2346251  5.487149  7.027044  2.5468866
# 2  6.628716                         0.6833034 13.089199  9.416353 22.5587981
# 3  2.004045                        -0.2546035  2.359135 -1.026871 -0.5567456
# 4  6.279847                         8.9205666 12.400832 14.073293 24.0311585
# 5 11.931889                        18.7635360 21.552882  7.813229 27.0491346
# 6  6.264070                         4.8123752 10.557367 12.641964  8.5886733
#   Z.Uterus   Z.Vagina   Z.Whole_Blood
# 1 -0.1362118  2.1723142  5.9151113
# 2 17.2580962 11.8672958 -1.6162722
# 3 -1.7883616  0.9674082 -0.1272477
# 4  8.0826706  6.6972577 10.8676430
# 5 13.2353362 13.8871454 23.4355154
# 6  3.3484950  7.1345965  8.2479002

# %%
nrow(r_all_gtex)
# Out:
# [1] 6807

# %%
ru0 = r_all_gtex[order(abs(r_all_gtex$Z.FPP.D11), decreasing = T),]
# ru0 = ru0[-which(duplicated(ru0$feature_id)),]
head(ru0,2)
nrow(ru0)
length(unique(ru0$feature_id))

mat0 = ru0[,-c(1,2)]
rownames(mat0) <- paste0(ru0$feature_id,"-",ru0$snp_id)
head(mat0,2)
# Out:
#   snp_id          feature_id      Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11 Z.DA.D30
# 1 17_7145981_T_C  ENSG00000170291 17.60191  19.06328    7.378654  1.520777
# 2 22_17680519_A_C ENSG00000093072 17.21335  16.47538    9.035217 11.335143
#   Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52  ⋯
# 1 13.48673   11.883131   13.32917     3.992745 ⋯
# 2 13.02668    8.723859   10.85849    11.971600 ⋯
#   Z.Skin_Not_Sun_Exposed_Suprapubic Z.Skin_Sun_Exposed_Lower_leg
# 1  8.062412                         10.03816
# 2 18.796729                         25.02792
#   Z.Small_Intestine_Terminal_Ileum Z.Spleen  Z.Stomach Z.Testis Z.Thyroid
# 1 1.144704                         0.2346251  5.487149 7.027044  2.546887
# 2 6.628716                         0.6833034 13.089199 9.416353 22.558798
#   Z.Uterus   Z.Vagina  Z.Whole_Blood
# 1 -0.1362118  2.172314  5.915111
# 2 17.2580962 11.867296 -1.616272
# [1] 6807
# [1] 6807
#                                 Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11 Z.DA.D30
# ENSG00000170291-17_7145981_T_C  17.60191  19.06328    7.378654  1.520777
# ENSG00000093072-22_17680519_A_C 17.21335  16.47538    9.035217 11.335143
#                                 Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52
# ENSG00000170291-17_7145981_T_C  13.48673   11.883131   13.32917     3.992745
# ENSG00000093072-22_17680519_A_C 13.02668    8.723859   10.85849    11.971600
#                                 Z.Sert.D52 Z.Epen1.D52 ⋯
# ENSG00000170291-17_7145981_T_C  18.89642   15.12826    ⋯
# ENSG00000093072-22_17680519_A_C 17.40637   15.56394    ⋯
#                                 Z.Skin_Not_Sun_Exposed_Suprapubic
# ENSG00000170291-17_7145981_T_C   8.062412
# ENSG00000093072-22_17680519_A_C 18.796729
#                                 Z.Skin_Sun_Exposed_Lower_leg
# ENSG00000170291-17_7145981_T_C  10.03816
# ENSG00000093072-22_17680519_A_C 25.02792
#                                 Z.Small_Intestine_Terminal_Ileum Z.Spleen
# ENSG00000170291-17_7145981_T_C  1.144704                         0.2346251
# ENSG00000093072-22_17680519_A_C 6.628716                         0.6833034
#                                 Z.Stomach Z.Testis Z.Thyroid Z.Uterus
# ENSG00000170291-17_7145981_T_C   5.487149 7.027044  2.546887 -0.1362118
# ENSG00000093072-22_17680519_A_C 13.089199 9.416353 22.558798 17.2580962
#                                 Z.Vagina  Z.Whole_Blood
# ENSG00000170291-17_7145981_T_C   2.172314  5.915111
# ENSG00000093072-22_17680519_A_C 11.867296 -1.616272

# %%
mat0_neuro = mat0[,grep(".D",colnames(mat0))]
mat0_brain = mat0[,grep("Brain",colnames(mat0))]
mat0_cell_lines = mat0[,grep("ransf",colnames(mat0))]
mat0_rest = mat0[,!(colnames(mat0) %in% c(colnames(mat0_neuro),colnames(mat0_brain),colnames(mat0_cell_lines)))]
mat0 = cbind(mat0_neuro, mat0_brain, mat0_cell_lines, mat0_rest)

# %%
new_mat = cor(mat0)
rownames(new_mat) <- gsub("Z.","",rownames(new_mat))
colnames(new_mat) <- gsub("Z.","",colnames(new_mat))

# %%
m = min(new_mat)
M = max(new_mat)
options(repr.plot.width = 14, repr.plot.height = 12)
Heatmap(new_mat, cluster_rows = F, cluster_columns = F, col = colorRamp2(c(m, M), c("white", "firebrick")), 
       name = "Z score \ncorrelations")
# Out:
# plot without title

# %%
##### first try,
### just concatenate and do PCA on everything

# %%
pca0 = prcomp(t(mat0))
pcs0 = pca0$x
head(pcs0)

pca_df0 = as.data.frame(pcs0)
# Out:
#             PC1       PC2         PC3        PC4       PC5         PC6
# Z.FPP.D11   -116.3166 -135.049542   3.293126 -63.85107  71.1416375 -32.05055
# Z.P_FPP.D11 -118.7602 -135.893030  -3.260364 -75.07076  75.3200414 -33.33599
# Z.NB.D11    -124.2958   -1.056123 -34.133661 -31.30957   3.3604983 -36.06669
# Z.DA.D30    -123.1852  -44.446958  17.505720  34.09078  -0.5511765  12.05003
# Z.Sert.D30  -114.8797  -49.301744   4.017657  34.82443 -20.3548732  12.27541
# Z.Epen1.D30 -121.2156  -50.929111   3.549664  38.80790 -40.7089702  11.03549
#             PC7       PC8       PC9        PC10       ⋯ PC50       PC51
# Z.FPP.D11    35.67652 -17.56075  15.396445 -15.481733 ⋯  2.3692417  2.31409418
# Z.P_FPP.D11  40.61024 -16.72816  11.459008 -14.992485 ⋯ -1.9930526 -2.58954409
# Z.NB.D11     11.06940 -19.56449  13.304574  23.857532 ⋯ -0.7638958 -0.48113842
# Z.DA.D30    -25.61043 -27.10903 -25.276874  22.027378 ⋯ -1.4114233 -0.05943834
# Z.Sert.D30  -11.51521 -18.56109  -8.401511   2.976355 ⋯ -2.2181728 -0.63568837
# Z.Epen1.D30 -11.96486  38.90674   7.258504  11.960007 ⋯  2.2676251  0.32016197
#             PC52         PC53       PC54        PC55      PC56       PC57
# Z.FPP.D11    0.003750865  4.1583061 -1.25721561 -3.347784 -3.9687316  2.1417718
# Z.P_FPP.D11  0.343870614 -3.2529397  1.70926486  3.204319  3.6553935 -1.3096293
# Z.NB.D11    -0.607722892 -1.0582619  0.78815821  1.916180  0.9450723 -1.1708315
# Z.DA.D30    -3.233755743 -0.5278062  0.45893485 -1.273183  1.3027718  0.4924974
# Z.Sert.D30  -0.495194394  1.6273290 -0.00191446  1.052521 -2.6886748 -1.5669585
# Z.Epen1.D30  1.289496167  1.4844779 -0.38917480  1.538936 -0.9787066  1.2219820
#             PC58       PC59
# Z.FPP.D11   -0.7491809 -2.048361e-14
# Z.P_FPP.D11  0.2448191 -1.643130e-14
# Z.NB.D11     1.1570318 -1.365574e-14
# Z.DA.D30     1.3434386 -2.087219e-14
# Z.Sert.D30  -1.5991725 -1.421085e-14
# Z.Epen1.D30  0.1554609 -2.275957e-14

# %%
df0 = data.frame(celltype = gsub("-.*","",gsub("Z-","",gsub("\\.","-",rownames(pca_df0)))), 
                                day = gsub(".*.D","D",rownames(pca_df0)),
                                PC1 = pca_df0$PC1, PC2 = pca_df0$PC2,
                PC3 = pca_df0$PC3, PC4 = pca_df0$PC4)
head(df0,2)

df0[!(df0$day %in% c("D11","D30","D52")),"day"] <- "NA"
df0[grep(("Brain"),df0$celltype),"day"] <- "Brain"
# df0

ggplot(df0, aes(x = PC1, y = PC2, colour = day)) + 
    geom_point(size = 3) +  #scale_color_manual(values=c(col_Astro, col_DA, col_Epen1,
#                                                 col_FPP, col_NB, col_P_FPP, col_Sert)) + 
theme_minimal()
# Out:
#   celltype day PC1       PC2       PC3       PC4
# 1 FPP      D11 -116.3166 -135.0495  3.293126 -63.85107
# 2 P_FPP    D11 -118.7602 -135.8930 -3.260364 -75.07076
# plot without title

# %%
matZ_0 = pcs0 %*% t(pcs0)
# matZ_0 = pcs0[,-c(1)] %*% t(pcs0[,-c(1)] )
# head(matZ_0)

# %%
rownames(matZ_0) <- gsub("Z.","",rownames(matZ_0))
colnames(matZ_0) <- gsub("Z.","",colnames(matZ_0))

# %%
# library(ComplexHeatmap)
# library(circlize)

m = min(matZ_0)
M = max(matZ_0)
options(repr.plot.width = 14, repr.plot.height = 12)
Heatmap(matZ_0, cluster_rows = F, cluster_columns = F, col = colorRamp2(c(m, M), c("white", "firebrick")), 
       name = "Z score - based \nsimilarity")
# Out:
# plot without title

# %%
matZ_0_norm = t(matZ_0/sqrt(diag(matZ_0))) /sqrt(diag(matZ_0))

# %%
m = min(matZ_0_norm)
M = max(matZ_0_norm)
options(repr.plot.width = 14, repr.plot.height = 12)
Heatmap(matZ_0_norm, cluster_rows = F, cluster_columns = F, col = colorRamp2(c(m, M), c("white", "firebrick")), 
       name = "Z score based\nsimilarity")
# Out:
# plot without title

# %%
# library(ComplexHeatmap)
# library(circlize)

m = min(matZ_0)
M = max(matZ_0)
options(repr.plot.width = 14, repr.plot.height = 12)
Heatmap(matZ_0, cluster_rows = F, cluster_columns = F, col = colorRamp2(c(m, M), c("white", "firebrick")), 
       name = "Z score \ncorrelations")
# Out:
# plot without title

# %%
##### second try,
### PCA on neuro and then map gtex

# %%
mat_neuro = mat0[,grep(".D",colnames(mat0))]
mat_gtex = mat0[,!(colnames(mat0) %in% colnames(mat_neuro))]
head(mat_neuro,2)
head(mat_gtex,2)
# Out:
#                                 Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11 Z.DA.D30
# ENSG00000170291-17_7145981_T_C  17.60191  19.06328    7.378654  1.520777
# ENSG00000093072-22_17680519_A_C 17.21335  16.47538    9.035217 11.335143
#                                 Z.Sert.D30 Z.Epen1.D30 Z.Astro.D30 Z.DA.D52
# ENSG00000170291-17_7145981_T_C  13.48673   11.883131   13.32917     3.992745
# ENSG00000093072-22_17680519_A_C 13.02668    8.723859   10.85849    11.971600
#                                 Z.Sert.D52 Z.Epen1.D52 Z.Astro.D52
# ENSG00000170291-17_7145981_T_C  18.89642   15.12826    10.205351
# ENSG00000093072-22_17680519_A_C 17.40637   15.56394     9.950645
#                                 Z.Adipose_Subcutaneous
# ENSG00000170291-17_7145981_T_C   7.371124
# ENSG00000093072-22_17680519_A_C 16.912939
#                                 Z.Adipose_Visceral_Omentum Z.Adrenal_Gland
# ENSG00000170291-17_7145981_T_C   5.68831                   -4.760596
# ENSG00000093072-22_17680519_A_C 18.84910                   10.012260
#                                 Z.Artery_Aorta Z.Artery_Coronary
# ENSG00000170291-17_7145981_T_C   9.921844      3.680077
# ENSG00000093072-22_17680519_A_C 16.479247      8.507993
#                                 Z.Artery_Tibial Z.Brain_Amygdala
# ENSG00000170291-17_7145981_T_C   9.064535       3.192255
# ENSG00000093072-22_17680519_A_C 18.708068       2.732176
#                                 Z.Brain_Anterior_cingulate_cortex_BA24
# ENSG00000170291-17_7145981_T_C  2.660494
# ENSG00000093072-22_17680519_A_C 2.863888
#                                 Z.Brain_Caudate_basal_ganglia
# ENSG00000170291-17_7145981_T_C  3.948196
# ENSG00000093072-22_17680519_A_C 6.856381
#                                 Z.Brain_Cerebellar_Hemisphere ⋯
# ENSG00000170291-17_7145981_T_C   0.2847583                    ⋯
# ENSG00000093072-22_17680519_A_C 11.9360959                    ⋯
#                                 Z.Skin_Not_Sun_Exposed_Suprapubic
# ENSG00000170291-17_7145981_T_C   8.062412
# ENSG00000093072-22_17680519_A_C 18.796729
#                                 Z.Skin_Sun_Exposed_Lower_leg
# ENSG00000170291-17_7145981_T_C  10.03816
# ENSG00000093072-22_17680519_A_C 25.02792
#                                 Z.Small_Intestine_Terminal_Ileum Z.Spleen
# ENSG00000170291-17_7145981_T_C  1.144704                         0.2346251
# ENSG00000093072-22_17680519_A_C 6.628716                         0.6833034
#                                 Z.Stomach Z.Testis Z.Thyroid Z.Uterus
# ENSG00000170291-17_7145981_T_C   5.487149 7.027044  2.546887 -0.1362118
# ENSG00000093072-22_17680519_A_C 13.089199 9.416353 22.558798 17.2580962
#                                 Z.Vagina  Z.Whole_Blood
# ENSG00000170291-17_7145981_T_C   2.172314  5.915111
# ENSG00000093072-22_17680519_A_C 11.867296 -1.616272

# %%
pca = prcomp(t(mat_neuro))

# %%
pcs_neuro = pca$x
head(pcs_neuro,2)
# Out:
#             PC1       PC2      PC3       PC4       PC5       PC6      PC7
# Z.FPP.D11   -137.0420 5.809664 -14.85397  8.918251 -1.397106 2.710829 -2.688208
# Z.P_FPP.D11 -148.0829 8.053664 -10.84626 15.531511  7.256221 7.390876  2.429585
#             PC8       PC9       PC10      PC11
# Z.FPP.D11   -3.432546 -8.389158 -63.90208 -3.520795e-14
# Z.P_FPP.D11 -9.114148  6.958649  59.13897 -4.996004e-14

# %%
loadings = pca$rotation
# head(loadings,2)

pcs_gtex = t(as.matrix(mat_gtex)) %*% as.matrix(loadings)
head(pcs_gtex,2)
# Out:
#                            PC1       PC2      PC3        PC4      PC5
# Z.Adipose_Subcutaneous     -37.29414 3.100178 -108.61599 21.80258 -8.246657
# Z.Adipose_Visceral_Omentum -30.69102 4.445970  -98.07925 17.76847 -7.469187
#                            PC6       PC7       PC8      PC9       PC10
# Z.Adipose_Subcutaneous     10.342409 -6.746997 16.87379  1.325515 -7.231747
# Z.Adipose_Visceral_Omentum  9.693559 -6.438071 12.61263 -1.835331 -6.810082
#                            PC11
# Z.Adipose_Subcutaneous     -16.38788
# Z.Adipose_Visceral_Omentum -11.02121

# %%
pcs = t(cbind(t(pcs_neuro), t(pcs_gtex)))
# pcs = scale(pcs)

# %%
pcs_df = as.data.frame(pcs)
df0 = data.frame(celltype = gsub("-.*","",gsub("Z-","",gsub("\\.","-",rownames(pcs_df)))), 
                                day = gsub(".*.D","D",rownames(pcs_df)),
                                PC1 = pcs_df$PC1, PC2 = pcs_df$PC2,
                PC3 = pcs_df$PC3, PC4 = pcs_df$PC4)
head(df0,2)

df0[!(df0$day %in% c("D11","D30","D52")),"day"] <- "NA"
df0[grep(("Brain"),df0$celltype),"day"] <- "Brain"
# df0

ggplot(df0, aes(x = PC1, y = PC2, colour = day)) + 
    geom_point(size = 3) +  #scale_color_manual(values=c(col_Astro, col_DA, col_Epen1,
#                                                 col_FPP, col_NB, col_P_FPP, col_Sert)) + 
theme_minimal()
# Out:
#   celltype day PC1       PC2      PC3       PC4
# 1 FPP      D11 -137.0420 5.809664 -14.85397  8.918251
# 2 P_FPP    D11 -148.0829 8.053664 -10.84626 15.531511
# plot without title

# %%
matZ = pcs %*% t(pcs)
head(matZ)
# Out:
#             Z.FPP.D11 Z.P_FPP.D11 Z.NB.D11   Z.DA.D30  Z.Sert.D30 Z.Epen1.D30
# Z.FPP.D11   23296.608 16837.1656  -1000.3358 -5529.613 -5399.9342 -6703.2806
# Z.P_FPP.D11 16837.166 26094.3659   -988.2962 -5511.745 -5758.9386 -6657.4137
# Z.NB.D11    -1000.336  -988.2962  21183.2619 -1210.601 -1024.3061 -1451.6284
# Z.DA.D30    -5529.613 -5511.7446  -1210.6012 15593.275  2026.3661 -1565.9391
# Z.Sert.D30  -5399.934 -5758.9386  -1024.3061  2026.366 13988.2082  -887.4361
# Z.Epen1.D30 -6703.281 -6657.4137  -1451.6284 -1565.939  -887.4361 16564.8591
#             Z.Astro.D30 Z.DA.D52   Z.Sert.D52 Z.Epen1.D52 ⋯
# Z.FPP.D11   -4489.81439 -4193.8413 -3182.357  -4445.874   ⋯
# Z.P_FPP.D11 -4355.97620 -4937.1299 -3907.295  -5238.465   ⋯
# Z.NB.D11    -2158.41221 -2982.6297 -5315.138  -5609.753   ⋯
# Z.DA.D30       80.06867  4475.8531 -1887.844  -4307.469   ⋯
# Z.Sert.D30    169.58959  -666.6392  2167.501  -2957.626   ⋯
# Z.Epen1.D30  2758.17159 -3209.0957 -3260.004   3793.518   ⋯
#             Z.Skin_Not_Sun_Exposed_Suprapubic Z.Skin_Sun_Exposed_Lower_leg
# Z.FPP.D11     6781.687                          7881.271
# Z.P_FPP.D11   5862.278                          6870.722
# Z.NB.D11    -12334.296                        -13986.501
# Z.DA.D30     -3158.553                         -3567.157
# Z.Sert.D30   -2019.996                         -2165.908
# Z.Epen1.D30  -3271.353                         -4061.335
#             Z.Small_Intestine_Terminal_Ileum Z.Spleen   Z.Stomach  Z.Testis
# Z.FPP.D11    2518.2263                        3403.7231   4524.021  5161.361
# Z.P_FPP.D11  2157.1444                        3120.2581   3767.404  5135.271
# Z.NB.D11    -6566.5404                       -7643.4382 -10519.747 -9836.632
# Z.DA.D30    -1612.5227                       -1620.9160  -2920.162 -2981.660
# Z.Sert.D30   -614.7272                        -871.3756  -1129.909 -2256.708
# Z.Epen1.D30 -1494.0176                       -1971.1209  -2617.983 -1361.359
#             Z.Thyroid  Z.Uterus   Z.Vagina   Z.Whole_Blood
# Z.FPP.D11     5179.617  2462.0974  2652.9117  5364.106
# Z.P_FPP.D11   3430.329  1687.3105  2132.1293  5155.546
# Z.NB.D11    -16604.300 -6007.5065 -5745.2612 -9244.756
# Z.DA.D30     -3863.160 -1130.3389 -1213.2546 -2387.542
# Z.Sert.D30   -1512.296  -785.6476  -618.6159 -1586.675
# Z.Epen1.D30  -2975.585 -1371.1730 -1537.8999 -2842.992

# %%
rownames(matZ) <- gsub("Z.","",rownames(matZ))
colnames(matZ) <- gsub("Z.","",colnames(matZ))

# matZ = scale(t(scale(matZ)))
m = min(matZ)
M = max(matZ)
options(repr.plot.width = 12, repr.plot.height = 10)
Heatmap(matZ, cluster_rows = F, cluster_columns = F, col = colorRamp2(c(m, M), c("white", "firebrick")), 
       name = "Z score \ncorrelations")
# Out:
# plot without title

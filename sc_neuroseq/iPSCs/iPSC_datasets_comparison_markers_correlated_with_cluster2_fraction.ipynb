# %%
library(ggplot2)
library(dplyr)

# %%
mydir = "/hps/nobackup/stegle/users/acuomo/all_scripts/sc_neuroseq/iPSC_scanpy/"

# %%
filename = paste0(mydir,'Cuomo2020.cluster_expression_markers.cluster2.tsv')
df0 = read.csv(filename, sep = "\t")
head(df0)
# Out:
#   names                  pvals         pvals_adj     logfoldchanges scores
# 1 ENSG00000152977_ZIC1    0.000000e+00  0.000000e+00 5.223554       44.32686
# 2 ENSG00000171794_UTF1   4.888347e-309 1.372526e-305 5.161236       42.95228
# 3 ENSG00000168505_GBX2   8.179711e-318 4.593317e-314 4.338133       42.70763
# 4 ENSG00000087510_TFAP2C 9.543329e-315 3.572704e-311 3.619993       42.21874
# 5 ENSG00000198417_MT1F   7.004946e-293 1.573451e-289 4.939952       40.33395
# 6 ENSG00000164093_PITX2  5.487019e-248 7.379923e-245 5.067068       37.91035
#   cluster_id ensembl_gene_id hgnc_symbol
# 1 2          ENSG00000152977 ZIC1
# 2 2          ENSG00000171794 UTF1
# 3 2          ENSG00000168505 GBX2
# 4 2          ENSG00000087510 TFAP2C
# 5 2          ENSG00000198417 MT1F
# 6 2          ENSG00000164093 PITX2

# %%
#### v0

# %%
filename = paste0(mydir,'Sarkar2019.cluster_expression_markers.cluster2.tsv')
df1 = read.csv(filename, sep = "\t")
df1$ensembl_gene_id = df1$names
head(df1)
# Out:
#   names           pvals         pvals_adj     logfoldchanges scores
# 1 ENSG00000110492  0.000000e+00  0.000000e+00 0.9017377      45.93811
# 2 ENSG00000166426 2.168760e-301 2.185135e-297 1.2323605      41.87468
# 3 ENSG00000198417 4.955173e-246 3.328390e-242 1.6254359      36.85649
# 4 ENSG00000125148 2.108466e-224 1.062193e-220 1.5340148      34.86892
# 5 ENSG00000176014 1.771280e-201 5.948844e-198 1.0946892      32.74362
# 6 ENSG00000110092 9.739693e-189 2.803779e-185 0.9947406      31.59857
#   cluster_id ensembl_gene_id
# 1 2          ENSG00000110492
# 2 2          ENSG00000166426
# 3 2          ENSG00000198417
# 4 2          ENSG00000125148
# 5 2          ENSG00000176014
# 6 2          ENSG00000110092

# %%
df = inner_join(df0,df1, by = c('ensembl_gene_id'), suffix = c(".Cuomo",".Sarkar"))
head(df)
# Out:
# Warning message:
# “Column `ensembl_gene_id` joining factors with different levels, coercing to character vector”
#   names.Cuomo            pvals.Cuomo   pvals_adj.Cuomo logfoldchanges.Cuomo
# 1 ENSG00000152977_ZIC1    0.000000e+00  0.000000e+00   5.223554
# 2 ENSG00000171794_UTF1   4.888347e-309 1.372526e-305   5.161236
# 3 ENSG00000168505_GBX2   8.179711e-318 4.593317e-314   4.338133
# 4 ENSG00000087510_TFAP2C 9.543329e-315 3.572704e-311   3.619993
# 5 ENSG00000198417_MT1F   7.004946e-293 1.573451e-289   4.939952
# 6 ENSG00000164093_PITX2  5.487019e-248 7.379923e-245   5.067068
#   scores.Cuomo cluster_id.Cuomo ensembl_gene_id hgnc_symbol names.Sarkar
# 1 44.32686     2                ENSG00000152977 ZIC1        ENSG00000152977
# 2 42.95228     2                ENSG00000171794 UTF1        ENSG00000171794
# 3 42.70763     2                ENSG00000168505 GBX2        ENSG00000168505
# 4 42.21874     2                ENSG00000087510 TFAP2C      ENSG00000087510
# 5 40.33395     2                ENSG00000198417 MT1F        ENSG00000198417
# 6 37.91035     2                ENSG00000164093 PITX2       ENSG00000164093
#   pvals.Sarkar  pvals_adj.Sarkar logfoldchanges.Sarkar scores.Sarkar
# 1  6.001952e-96  2.325872e-93    1.9561045             21.64928
# 2 1.014773e-176 2.556086e-173    2.2950571             30.50853
# 3  3.943575e-54  3.802248e-52    1.8450098             15.85210
# 4  3.970562e-28  1.363046e-26    0.9105303             11.10822
# 5 4.955173e-246 3.328390e-242    1.6254359             36.85649
# 6  6.269838e-61  7.345552e-59    1.7066220             16.87322
#   cluster_id.Sarkar
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2

# %%
nrow(df)
cor(df$logfoldchanges.Cuomo, df$logfoldchanges.Sarkar)
# Out:
# [1] 10951
# [1] 0.4009476

# %%
### v0 (all genes)
options(repr.plot.width=5, repr.plot.height=4.8)
ggplot(df, aes(x = logfoldchanges.Cuomo, y = logfoldchanges.Sarkar)) + geom_point(alpha = 0.8) + 
    xlab("Log Fold Change between cluster 2 \nand other clusters (Cuomo 2020)") + 
    ylab("Log Fold Change between cluster 2 \nand other clusters (Sarkar 2019)") + 
    xlim(c(-5,5)) + ylim(c(-3,3)) + theme_bw()  + theme(axis.title = element_text(size = 16))
# Out:
# Warning message:
# “Removed 10 rows containing missing values (geom_point).”
# plot without title

# %%
df1 = df1[df1$pvals_adj<0.05,]
df = inner_join(df0,df1, by = c('ensembl_gene_id'), suffix = c(".Cuomo",".Sarkar"))
head(df)
# Out:
# Warning message:
# “Column `ensembl_gene_id` joining factors with different levels, coercing to character vector”
#   names.Cuomo            pvals.Cuomo   pvals_adj.Cuomo logfoldchanges.Cuomo
# 1 ENSG00000152977_ZIC1    0.000000e+00  0.000000e+00   5.223554
# 2 ENSG00000171794_UTF1   4.888347e-309 1.372526e-305   5.161236
# 3 ENSG00000168505_GBX2   8.179711e-318 4.593317e-314   4.338133
# 4 ENSG00000087510_TFAP2C 9.543329e-315 3.572704e-311   3.619993
# 5 ENSG00000198417_MT1F   7.004946e-293 1.573451e-289   4.939952
# 6 ENSG00000164093_PITX2  5.487019e-248 7.379923e-245   5.067068
#   scores.Cuomo cluster_id.Cuomo ensembl_gene_id hgnc_symbol names.Sarkar
# 1 44.32686     2                ENSG00000152977 ZIC1        ENSG00000152977
# 2 42.95228     2                ENSG00000171794 UTF1        ENSG00000171794
# 3 42.70763     2                ENSG00000168505 GBX2        ENSG00000168505
# 4 42.21874     2                ENSG00000087510 TFAP2C      ENSG00000087510
# 5 40.33395     2                ENSG00000198417 MT1F        ENSG00000198417
# 6 37.91035     2                ENSG00000164093 PITX2       ENSG00000164093
#   pvals.Sarkar  pvals_adj.Sarkar logfoldchanges.Sarkar scores.Sarkar
# 1  6.001952e-96  2.325872e-93    1.9561045             21.64928
# 2 1.014773e-176 2.556086e-173    2.2950571             30.50853
# 3  3.943575e-54  3.802248e-52    1.8450098             15.85210
# 4  3.970562e-28  1.363046e-26    0.9105303             11.10822
# 5 4.955173e-246 3.328390e-242    1.6254359             36.85649
# 6  6.269838e-61  7.345552e-59    1.7066220             16.87322
#   cluster_id.Sarkar
# 1 2
# 2 2
# 3 2
# 4 2
# 5 2
# 6 2

# %%
nrow(df)
cor(df$logfoldchanges.Cuomo, df$logfoldchanges.Sarkar)
# Out:
# [1] 5397
# [1] 0.7415552

# %%
### v0 (significant genes in Sarkar p_adj<0.05)
options(repr.plot.width=5, repr.plot.height=4.8)
ggplot(df, aes(x = logfoldchanges.Cuomo, y = logfoldchanges.Sarkar)) + geom_point(alpha = 0.8) + 
    xlab("Log Fold Change between cluster 2 \nand other clusters (Cuomo 2020)") + 
    ylab("Log Fold Change between cluster 2 \nand other clusters (Sarkar 2019)") + 
    xlim(c(-5,5)) + ylim(c(-3,3)) + theme_bw()  + theme(axis.title = element_text(size = 16))
# Out:
# Warning message:
# “Removed 4 rows containing missing values (geom_point).”
# plot without title

# %%
#### v1

# %%
filename = paste0(mydir,'Sarkar2019_v1.cluster_expression_markers.cluster3.tsv')
df1 = read.csv(filename, sep = "\t")
df1$ensembl_gene_id = df1$names
head(df1)
# Out:
#   names           pvals         pvals_adj     logfoldchanges scores
# 1 ENSG00000110492 1.809524e-241 3.646373e-237 1.318483       42.01449
# 2 ENSG00000198417 5.051434e-194 5.089572e-190 2.311232       34.99912
# 3 ENSG00000125148 1.035113e-190 6.952853e-187 2.192762       34.21578
# 4 ENSG00000166426 2.514630e-175 1.266808e-171 1.519177       32.68576
# 5 ENSG00000171794 1.311203e-174 5.284409e-171 2.754909       32.30835
# 6 ENSG00000110090 2.965331e-174 9.959065e-171 1.983511       31.99995
#   cluster_id ensembl_gene_id
# 1 3          ENSG00000110492
# 2 3          ENSG00000198417
# 3 3          ENSG00000125148
# 4 3          ENSG00000166426
# 5 3          ENSG00000171794
# 6 3          ENSG00000110090

# %%
df = inner_join(df0,df1, by = c('ensembl_gene_id'), suffix = c(".Cuomo",".Sarkar"))
head(df)
# Out:
# Warning message:
# “Column `ensembl_gene_id` joining factors with different levels, coercing to character vector”
#   names.Cuomo            pvals.Cuomo   pvals_adj.Cuomo logfoldchanges.Cuomo
# 1 ENSG00000152977_ZIC1    0.000000e+00  0.000000e+00   5.223554
# 2 ENSG00000171794_UTF1   4.888347e-309 1.372526e-305   5.161236
# 3 ENSG00000168505_GBX2   8.179711e-318 4.593317e-314   4.338133
# 4 ENSG00000087510_TFAP2C 9.543329e-315 3.572704e-311   3.619993
# 5 ENSG00000198417_MT1F   7.004946e-293 1.573451e-289   4.939952
# 6 ENSG00000164093_PITX2  5.487019e-248 7.379923e-245   5.067068
#   scores.Cuomo cluster_id.Cuomo ensembl_gene_id hgnc_symbol names.Sarkar
# 1 44.32686     2                ENSG00000152977 ZIC1        ENSG00000152977
# 2 42.95228     2                ENSG00000171794 UTF1        ENSG00000171794
# 3 42.70763     2                ENSG00000168505 GBX2        ENSG00000168505
# 4 42.21874     2                ENSG00000087510 TFAP2C      ENSG00000087510
# 5 40.33395     2                ENSG00000198417 MT1F        ENSG00000198417
# 6 37.91035     2                ENSG00000164093 PITX2       ENSG00000164093
#   pvals.Sarkar  pvals_adj.Sarkar logfoldchanges.Sarkar scores.Sarkar
# 1  1.987423e-84  3.607978e-82    2.275763              20.90335
# 2 1.311203e-174 5.284409e-171    2.754909              32.30835
# 3  2.464699e-43  5.427995e-42    1.925046              14.30839
# 4  2.164602e-38  3.839691e-37    1.343475              13.32505
# 5 5.051434e-194 5.089572e-190    2.311232              34.99912
# 6  1.583033e-56  6.292474e-55    2.011302              16.61248
#   cluster_id.Sarkar
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3
# 6 3

# %%
nrow(df)
cor(df$logfoldchanges.Cuomo, df$logfoldchanges.Sarkar)
# Out:
# [1] 10951
# [1] 0.3218196

# %%
### v1 (all genes)
options(repr.plot.width=5, repr.plot.height=4.8)
ggplot(df, aes(x = logfoldchanges.Cuomo, y = logfoldchanges.Sarkar)) + geom_point(alpha = 0.5) + 
    xlab("Log Fold Change between cluster 2 \nand other clusters (Cuomo 2020)") + 
    ylab("Log Fold Change between cluster 3 \nand other clusters (Sarkar 2019)") + 
    xlim(c(-5,5)) + ylim(c(-3,3)) + 
    theme_bw()  + theme(axis.title = element_text(size = 16))
# Out:
# Warning message:
# “Removed 12 rows containing missing values (geom_point).”
# plot without title

# %%
df1 = df1[df1$pvals<0.0001,]
df = inner_join(df0,df1, by = c('ensembl_gene_id'), suffix = c(".Cuomo",".Sarkar"))
head(df)
# Out:
# Warning message:
# “Column `ensembl_gene_id` joining factors with different levels, coercing to character vector”
#   names.Cuomo            pvals.Cuomo   pvals_adj.Cuomo logfoldchanges.Cuomo
# 1 ENSG00000152977_ZIC1    0.000000e+00  0.000000e+00   5.223554
# 2 ENSG00000171794_UTF1   4.888347e-309 1.372526e-305   5.161236
# 3 ENSG00000168505_GBX2   8.179711e-318 4.593317e-314   4.338133
# 4 ENSG00000087510_TFAP2C 9.543329e-315 3.572704e-311   3.619993
# 5 ENSG00000198417_MT1F   7.004946e-293 1.573451e-289   4.939952
# 6 ENSG00000164093_PITX2  5.487019e-248 7.379923e-245   5.067068
#   scores.Cuomo cluster_id.Cuomo ensembl_gene_id hgnc_symbol names.Sarkar
# 1 44.32686     2                ENSG00000152977 ZIC1        ENSG00000152977
# 2 42.95228     2                ENSG00000171794 UTF1        ENSG00000171794
# 3 42.70763     2                ENSG00000168505 GBX2        ENSG00000168505
# 4 42.21874     2                ENSG00000087510 TFAP2C      ENSG00000087510
# 5 40.33395     2                ENSG00000198417 MT1F        ENSG00000198417
# 6 37.91035     2                ENSG00000164093 PITX2       ENSG00000164093
#   pvals.Sarkar  pvals_adj.Sarkar logfoldchanges.Sarkar scores.Sarkar
# 1  1.987423e-84  3.607978e-82    2.275763              20.90335
# 2 1.311203e-174 5.284409e-171    2.754909              32.30835
# 3  2.464699e-43  5.427995e-42    1.925046              14.30839
# 4  2.164602e-38  3.839691e-37    1.343475              13.32505
# 5 5.051434e-194 5.089572e-190    2.311232              34.99912
# 6  1.583033e-56  6.292474e-55    2.011302              16.61248
#   cluster_id.Sarkar
# 1 3
# 2 3
# 3 3
# 4 3
# 5 3
# 6 3

# %%
nrow(df)
cor(df$logfoldchanges.Cuomo, df$logfoldchanges.Sarkar)
# Out:
# [1] 7259
# [1] 0.7330724

# %%
### v1 (significant genes in Sarkar p<0.0001)
options(repr.plot.width=5, repr.plot.height=4.8)
ggplot(df, aes(x = logfoldchanges.Cuomo, y = logfoldchanges.Sarkar)) + geom_point(alpha = 0.5) + 
    xlab("Log Fold Change between cluster 2 \nand other clusters (Cuomo 2020)") + 
    ylab("Log Fold Change between cluster 3 \nand other clusters (Sarkar 2019)") + 
    xlim(c(-5,5)) + ylim(c(-3,3)) + 
    theme_bw()  + theme(axis.title = element_text(size = 16))
# Out:
# Warning message:
# “Removed 4 rows containing missing values (geom_point).”
# plot without title

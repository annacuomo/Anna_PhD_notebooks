# %%
filename = "/nfs/leia/research/stegle/dseaton/hipsci/singlecell_neuroseq/data/data_processed/pool1_17_D52/qtl_analysis/predictive_model_score_gwas/top_qtl_results_all.txt"

# %%
df = read.csv(filename, sep = "\t")
df
# Out:
#    snp_id           p_value      beta       beta_se
# 1  2_240616465_G_A  2.100283e-06 -0.5621718 0.11851345
# 2  4_141532044_C_A  8.270322e-06 -0.3934752 0.08826145
# 3  9_96625188_T_C   9.966640e-07 -0.4116363 0.08413971
# 4  7_51456547_G_A   2.129096e-05 -0.3417188 0.08038732
# 5  17_74980528_A_C  1.153912e-05 -0.3110957 0.07092733
# 6  14_95651047_T_C  1.116150e-05 -0.4392338 0.09997686
# 7  1_242838374_T_C  2.699563e-07 -0.6308623 0.12265715
# 8  3_122046148_G_A  8.523567e-06 -0.5534983 0.12433714
# 9  22_44926018_A_T  4.764019e-05  0.2311117 0.05682731
# 10 15_101515268_A_G 4.555475e-05 -0.3006760 0.07374327
# 11 8_37975330_C_T   6.204131e-05 -0.3647830 0.09108397
# 12 10_44235982_G_C  1.686165e-05 -0.5102903 0.11859361
# 13 18_52935941_T_G  1.829398e-06 -0.4715647 0.09883128
# 14 16_19951900_C_T  2.997776e-05 -0.4388055 0.10513748
# 15 12_97339236_A_T  3.186320e-05  0.3900550 0.09376945
# 16 5_123760568_C_T  4.126535e-06 -0.2987394 0.06487416
# ...

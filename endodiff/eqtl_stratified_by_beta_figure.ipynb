# %%
df_beta1 = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/genetic_effect/MOFA1/eqtl_est_single_GxE_genetic_effects.csv", row.names=1)
df_beta2 = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/genetic_effect/MOFA2/eqtl_est_single_GxE_genetic_effects.csv", row.names=1)
df_beta5 = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/genetic_effect/MOFA5/eqtl_est_single_GxE_genetic_effects.csv", row.names=1)
df_beta10 = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/genetic_effect/MOFA10/eqtl_est_single_GxE_genetic_effects.csv", row.names=1)
df_beta20 = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/genetic_effect/MOFA20/eqtl_est_single_GxE_genetic_effects.csv", row.names=1)

# %%
nrow(df_beta1)
head(df_beta1,2)
# Out:
# [1] 188
#   beta      eqtl
# 0 0.1757708 ENSG00000006459_KDM7A_-7_139913409_G_A
# 1 0.2507333 ENSG00000008311_AASS_-7_121856717_A_G

# %%
nrow(df_beta2)
nrow(df_beta5)
nrow(df_beta10)
nrow(df_beta20)
# Out:
# [1] 222
# [1] 265
# [1] 322
# [1] 525

# %%
options(repr.plot.width = 8, repr.plot.height = 4)
xmax = 4.5
hist(df_beta1$beta, xlim = c(0,xmax))
hist(df_beta2$beta, xlim = c(0,xmax))
hist(df_beta5$beta, xlim = c(0,xmax))
hist(df_beta10$beta, xlim = c(0,xmax))
hist(df_beta20$beta, xlim = c(0,xmax))
# Out:
# Plot with title “Histogram of df_beta1$beta”
# Plot with title “Histogram of df_beta2$beta”
# Plot with title “Histogram of df_beta5$beta”
# Plot with title “Histogram of df_beta10$beta”
# Plot with title “Histogram of df_beta20$beta”

# %%
# stratify into bins, e.g. [0-0.5, 0.5-1, 1-1.5, 1.5-2, >2]

# %%
df0 = df_beta1
nrow(df0[df0$beta<0.25,])
nrow(df0[df0$beta>=0.25 & df0$beta<0.5,])
nrow(df0[df0$beta>=0.5 & df0$beta<1,])
nrow(df0[df0$beta>=1 & df0$beta<1.5,])
nrow(df0[df0$beta>=1.5 & df0$beta<2,])
nrow(df0[df0$beta>=2,])
# Out:
# [1] 99
# [1] 69
# [1] 18
# [1] 1
# [1] 0
# [1] 1

# %%
df0 = df_beta2
nrow(df0[df0$beta<0.25,])
nrow(df0[df0$beta>=0.25 & df0$beta<0.5,])
nrow(df0[df0$beta>=0.5 & df0$beta<1,])
nrow(df0[df0$beta>=1 & df0$beta<1.5,])
nrow(df0[df0$beta>=1.5 & df0$beta<2,])
nrow(df0[df0$beta>=2,])
# Out:
# [1] 123
# [1] 76
# [1] 21
# [1] 0
# [1] 1
# [1] 1

# %%
df0 = df_beta5
nrow(df0[df0$beta<0.25,])
nrow(df0[df0$beta>=0.25 & df0$beta<0.5,])
nrow(df0[df0$beta>=0.5 & df0$beta<1,])
nrow(df0[df0$beta>=1 & df0$beta<1.5,])
nrow(df0[df0$beta>=1.5 & df0$beta<2,])
nrow(df0[df0$beta>=2,])
# Out:
# [1] 129
# [1] 96
# [1] 36
# [1] 2
# [1] 1
# [1] 1

# %%
df0 = df_beta10
nrow(df0[df0$beta<0.25,])
nrow(df0[df0$beta>=0.25 & df0$beta<0.5,])
nrow(df0[df0$beta>=0.5 & df0$beta<1,])
nrow(df0[df0$beta>=1 & df0$beta<1.5,])
nrow(df0[df0$beta>=1.5 & df0$beta<2,])
nrow(df0[df0$beta>=2,])
# Out:
# [1] 143
# [1] 131
# [1] 42
# [1] 4
# [1] 1
# [1] 1

# %%
df0 = df_beta20
nrow(df0[df0$beta<0.25,])
nrow(df0[df0$beta>=0.25 & df0$beta<0.5,])
nrow(df0[df0$beta>=0.5 & df0$beta<1,])
nrow(df0[df0$beta>=1 & df0$beta<1.5,])
nrow(df0[df0$beta>=1.5 & df0$beta<2,])
nrow(df0[df0$beta>=2,])
# Out:
# [1] 237
# [1] 208
# [1] 71
# [1] 6
# [1] 2
# [1] 1

# %%
options(repr.plot.width = 5, repr.plot.height = 5)
opar <- par(lwd = 1.5)
barplot(c(nrow(df_beta1),nrow(df_beta2),nrow(df_beta5),nrow(df_beta10),nrow(df_beta20)), col = "black", 
#         border = c(col_ips, col_mesendo, col_defendo), 
        axes = 3, xlab = "MOFA factors used as environments", ylab="# eGenes")
barplot(c(nrow(df_beta1[df_beta1$beta<2,]),nrow(df_beta2[df_beta2$beta<2,]),
          nrow(df_beta5[df_beta5$beta<2,]),nrow(df_beta10[df_beta10$beta<2,]),
          nrow(df_beta20[df_beta20$beta<2,])), col = "black", 
#         border = c(col_ips, col_mesendo, col_defendo), 
        add = T)
barplot(c(nrow(df_beta1[df_beta1$beta<1,]),nrow(df_beta2[df_beta2$beta<1,]),
          nrow(df_beta5[df_beta5$beta<1,]),nrow(df_beta10[df_beta10$beta<1,]),
          nrow(df_beta20[df_beta20$beta<1,])), col = "darkblue", 
#         border = c(col_ips, col_mesendo, col_defendo), 
        add = T)
barplot(c(nrow(df_beta1[df_beta1$beta<0.5,]),nrow(df_beta2[df_beta2$beta<0.5,]),
          nrow(df_beta5[df_beta5$beta<0.5,]),nrow(df_beta10[df_beta10$beta<0.5,]),
          nrow(df_beta20[df_beta20$beta<0.5,])), col = "blue", 
#         border = c(col_ips, col_mesendo, col_defendo), 
        add = T)
barplot(c(nrow(df_beta1[df_beta1$beta<0.25,]),nrow(df_beta2[df_beta2$beta<0.2,]),
          nrow(df_beta5[df_beta5$beta<0.25,]),nrow(df_beta10[df_beta10$beta<0.2,]),
          nrow(df_beta20[df_beta20$beta<0.25,])), col = "cornflowerblue", 
#         border = c(col_ips, col_mesendo, col_defendo), 
        add = T)

# barplot(c(681,592,590), col = "gray65", border = c(col_ips, col_mesendo, col_defendo), add = T)
# Out:
# plot without title

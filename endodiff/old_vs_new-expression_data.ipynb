# %%
library(corrplot)

# %%
### old results
## MOFA (1:10)
## background with all 10 factors always
## y_gauss, E_gauss

# %%
# script: /hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/endodiff.py

# %%
# pheno_filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/exprs_alldays_allgenes.tsv"
# df0 = read.csv(pheno_filename, sep="\t", row.names=1)
nrow(df0)
ncol(df0)
df0[1:5,1:5]
# Out:
# [1] 11231
# [1] 36044
#                          X21843_1.10  X21843_1.100 X21843_1.101 X21843_1.102
# ENSG00000000003_TSPAN6   5.5207770563 6.4562078    5.878671     4.8608241
# ENSG00000000419_DPM1     5.3924605058 6.0659226    6.838769     6.6142685
# ENSG00000000457_SCYL3    0.0001741556 0.3525966    0.000000     0.8259555
# ENSG00000000460_C1orf112 1.4719275194 4.5369683    4.318528     5.3730090
# ENSG00000001036_FUCA2    2.9088018801 3.8673273    3.321747     3.7364760
#                          X21843_1.103
# ENSG00000000003_TSPAN6   5.903640
# ENSG00000000419_DPM1     6.512403
# ENSG00000000457_SCYL3    2.201697
# ENSG00000000460_C1orf112 4.636175
# ENSG00000001036_FUCA2    4.917576

# %%
### new results
## PCA (1:10)
## background same factors as tested (1:1 or 10:10)
## y_gauss, E_gauss

# %%
# script: /hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/April2021/endodiff_PCA.py

# %%
input_files_dir = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/input_files/"

# %%
# pheno_filename = paste0(input_files_dir, "phenotype.csv")
# df1 = read.csv(pheno_filename, row.names=1)
nrow(df1)
ncol(df1)
df1[1:5,1:5]
# Out:
# [1] 11231
# [1] 34256
#                          X21843_1.10  X21843_1.100 X21843_1.101 X21843_1.102
# ENSG00000000003_TSPAN6   5.5207770563 6.4562078    5.878671     4.8608241
# ENSG00000000419_DPM1     5.3924605058 6.0659226    6.838769     6.6142685
# ENSG00000000457_SCYL3    0.0001741556 0.3525966    0.000000     0.8259555
# ENSG00000000460_C1orf112 1.4719275194 4.5369683    4.318528     5.3730090
# ENSG00000001036_FUCA2    2.9088018801 3.8673273    3.321747     3.7364760
#                          X21843_1.103
# ENSG00000000003_TSPAN6   5.903640
# ENSG00000000419_DPM1     6.512403
# ENSG00000000457_SCYL3    2.201697
# ENSG00000000460_C1orf112 4.636175
# ENSG00000001036_FUCA2    4.917576

# %%
cells1 = colnames(df0)
cells2 = colnames(df1)
common_cells = cells1[cells1 %in% cells2]

# %%
df2 = t(df0[111:120,common_cells])
df3 = t(df1[111:120,common_cells])
df4 = cbind(df2,df3)

# %%
corrplot(cor(df4))
# Out:
# Plot with title “”

# %%
corrplot(cor(df4))
# Out:
# Plot with title “”

# %%
corrplot(cor(df4))
# Out:
# corrplot 0.84 loaded
# Plot with title “”

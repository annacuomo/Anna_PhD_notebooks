# %%
library(corrplot)
# Out:
# corrplot 0.84 loaded

# %%
### old results
## MOFA (1:10)
## background with all 10 factors always
## y_gauss, E_gauss

# %%
# script: /hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/endodiff.py

# %%
E_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/mofa_logcounts_model_factors.csv"
df0 = read.csv(E_file, row.names=1)
nrow(df0)
ncol(df0)
df0[1:5,1:5]
# Out:
# [1] 36044
# [1] 10
#             MOFA1       MOFA2    MOFA3       MOFA4     MOFA5
# 21843_1#10  -0.54978801 1.115838  0.09235695 1.4022501  0.64556476
# 21843_1#100  0.26934134 2.197342  0.70375016 0.9313924 -0.33624749
# 21843_1#101 -0.02561868 1.815617 -0.07399272 0.2909299  0.06909543
# 21843_1#102 -0.69904249 1.170264  0.17953677 0.5010695  1.54701071
# 21843_1#103 -0.22270389 1.551141 -0.15298686 0.2631688  0.79750270

# %%
### new results
## PCA (1:10)
## background same factors as tested (1:1 or 10:10)
## y_gauss, E_gauss

# %%
# script: /hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/April2021/endodiff_PCA.py

# %%
input_files_dir = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/input_files/"

# %%
E_file = paste0(input_files_dir,"20PCs.csv")
df1 = read.csv(E_file, row.names=1)
nrow(df1)
ncol(df1)
df1[1:5,1:5]
# Out:
# [1] 34256
# [1] 20
#             PC1        PC2       PC3        PC4        PC5
# 21843_1#10  -12.241231 -12.61522  0.5472086 -11.411204  -7.052088
# 21843_1#100   4.509125 -27.06629  7.5564469  -9.366868  -1.471991
# 21843_1#101  -1.273414 -23.32348 -0.5019034  -3.819575  -1.463243
# 21843_1#102 -14.962566 -12.96637  1.9674060  -5.446326 -13.316007
# 21843_1#103  -6.341665 -19.01047 -2.8249750  -2.462769  -7.521426

# %%
cells1 = rownames(df0)
cells2 = rownames(df1)
common_cells = cells1[cells1 %in% cells2]
length(common_cells)
# Out:
# [1] 34256

# %%
df0 = df0[common_cells,]
df1 = df1[common_cells,1:10]

# %%
df2 = cbind(df0,df1)

# %%
corrplot(cor(df2))
# Out:
# Plot with title “”

# %%
library(ggthemes)
options(repr.plot.width = 3, repr.plot.height = 3) 
require("scales")
for (i in 1:length(names(canva_palettes))){
    if (i %in% c(8,23,25,27,60,65,81,84,96,103,113,114)){
        print(show_col(canva_pal(names(canva_palettes)[i])(4)))   
        print(names(canva_palettes)[i])
    }
}
# Out:
# Loading required package: scales
# NULL
# [1] "Primary colors with a vibrant twist"
# plot without title
# NULL
# [1] "Summer sunflower"
# plot without title
# NULL
# [1] "Timeless and nautical"
# plot without title
# NULL
# [1] "Cheerful brights"
# plot without title
# NULL
# [1] "Candy coated brights"
# plot without title
# NULL
# [1] "Nightlife"
# plot without title
# NULL
# [1] "Warm and cool"
# plot without title
# NULL
# [1] "Pool party"
# plot without title
# NULL
# [1] "Bright and painterly"
# plot without title
# NULL
# [1] "Art history inspired"
# plot without title
# NULL
# [1] "Pretty pastels"
# plot without title
# NULL
# [1] "Bold and punchy"
# plot without title

# %%
names(canva_palettes)

# %%
library(ggthemes)
options(repr.plot.width = 3, repr.plot.height = 3) 
require("scales")
for (i in 1:length(names(canva_palettes))){
    print(show_col(canva_pal(names(canva_palettes)[i])(4)))   
    print(names(canva_palettes)[i])
}
# Out:
# NULL
# [1] "Fresh and bright"
# plot without title
# NULL
# [1] "Subdued and proffesional"
# plot without title
# NULL
# [1] "Dark and earthy"
# plot without title
# NULL
# [1] "Crisp and dramatic"
# plot without title
# NULL
# [1] "Cool blues"
# plot without title
# NULL
# [1] "Outdoorsy and Natural"
# plot without title
# NULL
# [1] "Watery blue-greens"
# plot without title
# NULL
# [1] "Primary colors with a vibrant twist"
# plot without title
# NULL
# [1] "Refreshing and pretty"
# plot without title
# NULL
# [1] "Playful greens and blues"
# plot without title
# NULL
# [1] "Fresh and energetic"
# plot without title
# NULL
# [1] "Surf and turf"
# plot without title
# NULL
# [1] "Autumn in vermont"
# plot without title
# NULL
# [1] "Icy blues and grays"
# plot without title
# NULL
# [1] "Birds and berries"
# plot without title
# NULL
# [1] "Day and night"
# plot without title
# NULL
# [1] "Stylish and retro"
# plot without title
# NULL
# [1] "Shades of citrus"
# plot without title
# NULL
# [1] "Sunset to dusk"
# plot without title
# NULL
# [1] "Bright and tropical"
# plot without title
# NULL
# [1] "Warm naturals"
# plot without title
# NULL
# [1] "Bold berries"
# plot without title
# NULL
# [1] "Summer sunflower"
# plot without title
# NULL
# [1] "Modern and crisp"
# plot without title
# NULL
# [1] "Timeless and nautical"
# plot without title
# NULL
# [1] "Neutral and versatile"
# plot without title
# NULL
# [1] "Cheerful brights"
# plot without title
# NULL
# [1] "Garden fresh"
# plot without title
# NULL
# [1] "Summer barbeque"
# plot without title
# NULL
# [1] "Berry blues"
# plot without title
# NULL
# [1] "Lemonade stand"
# plot without title
# NULL
# [1] "Serene and spa like"
# plot without title
# NULL
# [1] "Fun and tropical"
# plot without title
# NULL
# [1] "Spicy neutrals"
# plot without title
# NULL
# [1] "Pastels"
# plot without title
# NULL
# [1] "Bold and cultured"
# plot without title
# NULL
# [1] "Sunny citrus"
# plot without title
# NULL
# [1] "Crisp complementary colors"
# plot without title
# NULL
# [1] "Warm and rustic"
# plot without title
# NULL
# [1] "Neon night"
# plot without title
# NULL
# [1] "Jewel tones"
# plot without title
# NULL
# [1] "Polished and inviting"
# plot without title
# NULL
# [1] "Fresh greens"
# plot without title
# NULL
# [1] "Wintery reds"
# plot without title
# NULL
# [1] "Summer fiesta"
# plot without title
# NULL
# [1] "Chocolaty browns"
# plot without title
# NULL
# [1] "Naturally elegant"
# plot without title
# NULL
# [1] "Cozy and warm"
# plot without title
# NULL
# [1] "Violet sunset"
# plot without title
# NULL
# [1] "Strawberries and cream"
# plot without title
# NULL
# [1] "Grecian holiday"
# plot without title
# NULL
# [1] "Bold and basic"
# plot without title
# NULL
# [1] "Vineyard neutrals"
# plot without title
# NULL
# [1] "Modern and urban"
# plot without title
# NULL
# [1] "Misty greens"
# plot without title
# NULL
# [1] "Sunkissed village"
# plot without title
# NULL
# [1] "Sun and sky"
# plot without title
# NULL
# [1] "Aqua blues"
# plot without title
# NULL
# [1] "Urban oasis"
# plot without title
# NULL
# [1] "Candy coated brights"
# plot without title
# NULL
# [1] "Muted and antique"
# plot without title
# NULL
# [1] "Classy and timeless"
# plot without title
# NULL
# [1] "Cosmopolitan"
# plot without title
# NULL
# [1] "Cheerful and friendly"
# plot without title
# NULL
# [1] "Nightlife"
# plot without title
# NULL
# [1] "Coastal"
# plot without title
# NULL
# [1] "Maritime brights"
# plot without title
# NULL
# [1] "Vintage charm"
# plot without title
# NULL
# [1] "Understated and versatile"
# plot without title
# NULL
# [1] "Artic sunrise"
# plot without title
# NULL
# [1] "Mediterranean afternoon"
# plot without title
# NULL
# [1] "Hazy grays"
# plot without title
# NULL
# [1] "City sights"
# plot without title
# NULL
# [1] "Retro and relaxing"
# plot without title
# NULL
# [1] "Green fields"
# plot without title
# NULL
# [1] "Distintive and unexpected"
# plot without title
# NULL
# [1] "Sleek and modern"
# plot without title
# NULL
# [1] "Orange accent"
# plot without title
# NULL
# [1] "Beyond black and white"
# plot without title
# NULL
# [1] "Shabby chic neutrals"
# plot without title
# NULL
# [1] "Warm and cool"
# plot without title
# NULL
# [1] "Industrial and in control"
# plot without title
# NULL
# [1] "Autumn oranges and complemtentary neutrals"
# plot without title
# NULL
# [1] "Pool party"
# plot without title
# NULL
# [1] "Classic metallics"
# plot without title
# NULL
# [1] "Subtle and versatile"
# plot without title
# NULL
# [1] "Professional and traditional"
# plot without title
# NULL
# [1] "Light and natural"
# plot without title
# NULL
# [1] "Shadowy and dramatic"
# plot without title
# NULL
# [1] "Golden afternoon"
# plot without title
# NULL
# [1] "Dark and handsome"
# plot without title
# NULL
# [1] "Technology meets nature"
# plot without title
# NULL
# [1] "Cheerful blues and pink"
# plot without title
# NULL
# [1] "Exotic and high impact"
# plot without title
# NULL
# [1] "Back to school"
# plot without title
# NULL
# [1] "Bright and painterly"
# plot without title
# NULL
# [1] "Urban living"
# plot without title
# NULL
# [1] "1950s kitchen"
# plot without title
# NULL
# [1] "Smoky purples"
# plot without title
# NULL
# [1] "Trendy and metropolitan"
# NULL
# [1] "Trendy and metropolitan"
# plot without title
# NULL
# [1] "Fun and professional"
# plot without title
# NULL
# [1] "Art history inspired"
# plot without title
# NULL
# [1] "Muted tones"
# plot without title
# NULL
# [1] "Modern and clean"
# plot without title
# NULL
# [1] "Neon tones and sharp contrast"
# plot without title
# NULL
# [1] "Muted and minimal"
# plot without title
# NULL
# [1] "Warm and bold"
# plot without title
# NULL
# [1] "Clean and highlighted"
# plot without title
# NULL
# [1] "Warm tones"
# plot without title
# NULL
# [1] "Sharp and modern"
# plot without title
# NULL
# [1] "Cool vs warm"
# plot without title
# NULL
# [1] "Pretty pastels"
# plot without title
# NULL
# [1] "Bold and punchy"
# plot without title
# NULL
# [1] "Tints and tones"
# plot without title
# NULL
# [1] "Splash of color"
# Error in rect(col(colours) - 1, -row(colours) + 1, col(colours), -row(colours), : invalid RGB specification
# Traceback:
#
# 1. print(show_col(canva_pal(names(canva_palettes)[i])(4)))
# 2. show_col(canva_pal(names(canva_palettes)[i])(4))
# 3. rect(col(colours) - 1, -row(colours) + 1, col(colours), -row(colours),
#  .     col = colours, border = borders)
# plot without title
# plot without title

# %%
canva_pal("Muted and antique")(4)
# Out:
# [1] "#a4cabc" "#eab364" "#b2473e" "#acbd78"

# %%
show_col(canva_pal("Bold and punchy")(4))
canva_pal("Bold and punchy")(4)
# Out:
# [1] "#e24e42" "#e9b000" "#eb6e80" "#008f95"
# plot without title

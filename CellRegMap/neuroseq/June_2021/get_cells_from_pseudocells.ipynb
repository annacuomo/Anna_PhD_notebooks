# %%
filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/pseudocells_Danai/Pseudobulk_per_donor_DA_cells_all_conditions_Leiden_res34.h5"

# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read(filename)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8648 × 32738
#     obs: 'donor_id', 'celltype', 'time_point', 'treatment', 'Condition', 'leiden_res_34_euclidean', 'Number_of_cells', 'cell_ids'
#     var: 'MITO', 'RIBO', 'ERCC', 'gene_ids-0'

# %%
adata.obs
# Out:
#               donor_id celltype time_point treatment Condition  \
# 0     HPSI0714i-iudw_1       DA        D30      NONE       d30
# 1     HPSI0714i-iudw_1       DA        D30      NONE       d30
# 2     HPSI0714i-iudw_1       DA        D30      NONE       d30
# 3     HPSI0714i-iudw_1       DA        D30      NONE       d30
# 4     HPSI0714i-iudw_1       DA        D30      NONE       d30
# ...                ...      ...        ...       ...       ...
# 8643  HPSI0114i-rozh_4       DA        D52       ROT    d52_tr
# 8644  HPSI0114i-rozh_4       DA        D52       ROT    d52_tr
# 8645  HPSI0114i-rozh_4       DA        D52       ROT    d52_tr
# 8646  HPSI0114i-rozh_4       DA        D52       ROT    d52_tr
# 8647  HPSI0114i-rozh_4       DA        D52       ROT    d52_tr
#
#      leiden_res_34_euclidean  Number_of_cells  \
# 0                          0               26
# 1                          1               25
# 2                          2               24
# ...

# %%
adata.obs.to_csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/adata_obs_pseudocells_DA.csv")

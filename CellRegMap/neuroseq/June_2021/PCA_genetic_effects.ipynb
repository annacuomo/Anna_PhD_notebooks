# %%
library(ggplot2)
library(ggthemes)
library(corrplot)
# Out:
# corrplot 0.84 loaded

# %%
df = read.csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/May2021/genetic_effect/MOFA10/eqtl_tot_genetic_effect_all.txt", sep="\t",row.names = 1)
head(df)
# Out:
#                              ABHD10_.3_111697439_T_G ABHD12B_.14_51328222_C_T
# HPSI0714i-iudw_1--DA--d30--0 -0.2108622               0.003924475
# HPSI0714i-iudw_1--DA--d30--1 -0.2283969              -0.047217741
# HPSI0714i-iudw_1--DA--d30--2 -0.3702669              -0.187986589
# HPSI0714i-iudw_1--DA--d30--3 -0.4690041               0.016038409
# HPSI0714i-iudw_1--DA--d30--4  0.3503564              -0.236613003
# HPSI0714i-iudw_1--DA--d30--5  0.1012829              -0.244239442
#                              ACKR2_.3_42817129_C_T ADD2_.2_70894426_A_T
# HPSI0714i-iudw_1--DA--d30--0 0.02206444             0.02834211
# HPSI0714i-iudw_1--DA--d30--1 0.10596178             0.02514689
# HPSI0714i-iudw_1--DA--d30--2 0.11071216            -0.08986937
# HPSI0714i-iudw_1--DA--d30--3 0.08790047             0.05432180
# HPSI0714i-iudw_1--DA--d30--4 0.01487196            -0.12134894
# HPSI0714i-iudw_1--DA--d30--5 0.08520448            -0.14295098
# ...

# %%
pca = prcomp(df)

# %%
loadings = pca$rotation
head(loadings)
# Out:
#                          PC1         PC2         PC3         PC4
# ABHD10_.3_111697439_T_G   0.10288235 -0.03029193  0.10110367 -0.01550177
# ABHD12B_.14_51328222_C_T -0.02291588  0.07088373 -0.01279243 -0.03338384
# ACKR2_.3_42817129_C_T    -0.02937964 -0.01448766 -0.04988377  0.01674497
# ADD2_.2_70894426_A_T     -0.02432310  0.05039080  0.01408933 -0.01368305
# ADSL_.22_40757228_A_C     0.03270395 -0.05249378  0.07061207 -0.09750721
# AIM1L_.1_26673825_C_T     0.01599162 -0.02125504  0.02096633  0.02710308
#                          PC5          PC6          PC7         PC8
# ABHD10_.3_111697439_T_G   0.044579328 -0.036184340  0.25291167 -0.021818303
# ABHD12B_.14_51328222_C_T  0.022477566 -0.064067103  0.07050307 -0.095241767
# ACKR2_.3_42817129_C_T    -0.002425234  0.027625450  0.01250888  0.005124386
# ADD2_.2_70894426_A_T     -0.013392908 -0.003902099  0.02234229 -0.037882457
# ADSL_.22_40757228_A_C     0.070727387 -0.035486045  0.02634234  0.131450668
# ...

# %%
filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/May2021/pca_from_geneticeffects_loadings.csv"
write.csv(loadings, filename)

# %%
head(pca$x)
# Out:
#                              PC1        PC2        PC3        PC4
# HPSI0714i-iudw_1--DA--d30--0 -2.0338623 -1.0578996  1.0250942 -1.22248805
# HPSI0714i-iudw_1--DA--d30--1 -2.2147007 -0.4403134 -0.1042848  1.15530536
# HPSI0714i-iudw_1--DA--d30--2 -1.8900758 -1.9395208 -0.8666246 -0.03046018
# HPSI0714i-iudw_1--DA--d30--3 -2.7576812 -0.5790179  0.2488933 -0.19259794
# HPSI0714i-iudw_1--DA--d30--4  0.7696368 -1.9171999  0.1982543  0.11024864
# HPSI0714i-iudw_1--DA--d30--5 -0.1646888 -2.1042671 -0.5117111  0.23739310
#                              PC5         PC6       PC7          PC8
# HPSI0714i-iudw_1--DA--d30--0  0.02360833 0.3207118 -0.221886527  0.04843269
# HPSI0714i-iudw_1--DA--d30--1  0.23881558 0.9751289  0.008139807 -0.28370601
# HPSI0714i-iudw_1--DA--d30--2  0.13573405 0.3063380 -0.611993730  0.57911599
# HPSI0714i-iudw_1--DA--d30--3 -0.09845089 0.6193820 -0.547136026 -0.29454071
# HPSI0714i-iudw_1--DA--d30--4 -0.60553375 0.4682509  0.639187397  0.33741260
# ...

# %%
df0 = as.data.frame(pca$x)
nrow(df0)
# Out:
# [1] 8352

# %%
pcs_filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/May2021/mofa_logcounts_model_factors.csv"
df1 = read.csv(pcs_filename, row.names=1)

# %%
df1 = df1[rownames(df0),]
nrow(df1)
head(df1)
# Out:
# [1] 8352
#                              MOFA1      MOFA2        MOFA3      MOFA4
# HPSI0714i-iudw_1--DA--d30--0  1.6664557  0.589291718 -1.2180321  0.5332707
# HPSI0714i-iudw_1--DA--d30--1  1.7932753 -1.089708277  0.5161943  0.3031652
# HPSI0714i-iudw_1--DA--d30--2  1.4601733 -0.920466384  0.4333725  0.8382845
# HPSI0714i-iudw_1--DA--d30--3  2.1352168  0.007667889 -0.3406776  0.1694220
# HPSI0714i-iudw_1--DA--d30--4 -0.2996176 -1.471800929 -0.5598412 -0.2879682
# HPSI0714i-iudw_1--DA--d30--5  0.2949934 -1.601036803  0.1386558  0.3616551
#                              MOFA5       MOFA6       MOFA7      MOFA8
# HPSI0714i-iudw_1--DA--d30--0 -0.11471842 -0.70044968 -0.8720116 -0.7222332
# HPSI0714i-iudw_1--DA--d30--1 -0.37070591 -0.63629753  1.1359303  0.2466621
# HPSI0714i-iudw_1--DA--d30--2  0.04179157 -0.34931222 -0.5665099  0.0331838
# HPSI0714i-iudw_1--DA--d30--3 -0.48726664 -0.94746164  0.2343832 -0.4423545
# ...

# %%
df2 = cbind(df0[,1:10], df1[,1:10])
corrplot(cor(df2))
# Out:
# Plot with title “”

# %%
# coldata = data.frame(cell = colnames(sce0), day = sce0$day)
# head(coldata,2)
# Out:
#   cell        day
# 1 21843_1#10  day1
# 2 21843_1#100 day1

# %%
df_to_plot = cbind(sce0$day,df0)
colnames(df_to_plot)[1] = "day"
options(repr.plot.width = 7, repr.plot.height = 5)
ggplot(df_to_plot, aes(x = PC1, y = PC2, colour = day)) + geom_point(alpha = 0.2) + 
    scale_color_canva(palette = "Pool party") + theme_bw()
# Out:
# plot without title

# %%
########## FDR < 5%

# %%
#### real data (neuroseq)

# %%
options(repr.plot.width = 3, repr.plot.height = 5)
opar <- par(lwd = 3)
barplot(c(213,27), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes") 
barplot(c(213,53), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes") 
barplot(c(213,59), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes")
# Out:
# plot without title
# plot without title
# plot without title

# %%
########## FDR < 10%

# %%
#### real data (neuroseq)

# %%
options(repr.plot.width = 3, repr.plot.height = 5)
opar <- par(lwd = 3)
barplot(c(245,35), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes") 
barplot(c(245,83), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes") 
barplot(c(245,77), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes")
# Out:
# plot without title
# plot without title
# plot without title

# %%
#### simulated data

# %%
options(repr.plot.width = 3, repr.plot.height = 5)
opar <- par(lwd = 3)
barplot(c(434,58), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes") 
barplot(c(434,67), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes") 
barplot(c(434,108), border = "white", col = c("dodgerblue4","cornflowerblue"), ylab="Number of eGenes")
# Out:
# plot without title
# plot without title
# plot without title

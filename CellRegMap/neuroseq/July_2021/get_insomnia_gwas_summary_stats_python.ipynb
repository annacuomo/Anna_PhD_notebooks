# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_gwas_filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/da_coloc_GxC/1200.gwas.imputed_v3.both_sexes.tsv"
df_gwas = pd.read_csv(df_gwas_filename, sep="\t")
df_gwas.head()
# Out:
#          variant minor_allele      minor_AF  expected_min_category_minor_AC  \
# 0    1:15791:C:T            T  5.435480e-09                        0.000005
# 1    1:69487:G:A            A  5.756170e-06                        0.005250
# 2    1:69569:T:C            C  1.879590e-04                        0.171419
# 3   1:139853:C:T            T  5.669210e-06                        0.005170
# 4  1:692794:CA:C            C  1.106450e-01                      100.908000
#
#    low_confidence_variant  n_complete_samples            AC            ytx  \
# 0                    True              360738      0.003922       0.007843
# 1                    True              360738      4.152940       7.298040
# 2                    True              360738    135.608000     281.702000
# 3                    True              360738      4.090200       7.180390
# 4                   False              360738  79827.800000  162827.000000
#
#         beta          se     tstat      pval
# ...

# %%
df_gwas['chr'] = df_gwas['variant'].apply(lambda x: x.split(":")[0])
df_gwas['pos'] = df_gwas['variant'].apply(lambda x: x.split(":")[1])

# %%
import re
df_gwas['snp_id'] = df_gwas['variant'].apply(lambda x: re.sub(":","_",x))

# %%
df_gwas.head()
# Out:
#          variant minor_allele      minor_AF  expected_min_category_minor_AC  \
# 0    1:15791:C:T            T  5.435480e-09                        0.000005
# 1    1:69487:G:A            A  5.756170e-06                        0.005250
# 2    1:69569:T:C            C  1.879590e-04                        0.171419
# 3   1:139853:C:T            T  5.669210e-06                        0.005170
# 4  1:692794:CA:C            C  1.106450e-01                      100.908000
#
#    low_confidence_variant  n_complete_samples            AC            ytx  \
# 0                    True              360738      0.003922       0.007843
# 1                    True              360738      4.152940       7.298040
# 2                    True              360738    135.608000     281.702000
# 3                    True              360738      4.090200       7.180390
# 4                   False              360738  79827.800000  162827.000000
#
# ...

# %%
df_gwas.to_csv("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/gwas_insomnia_awith_pos.csv")

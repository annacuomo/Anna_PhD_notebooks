# %%
import pickle
import pandas as pd

# %%
filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/input_files/DA_all_conditions/phenotype.csv"

# %%
df = pd.read_csv(filename, index_col=0)
df.head()
# Out:
#                  iudw_1--cluster0  iudw_1--cluster1  iudw_1--cluster2  \
# ENSG00000243485                 0                 0                 0
# ENSG00000237613                 0                 0                 0
# ENSG00000186092                 0                 0                 0
# ENSG00000238009                 0                 0                 0
# ENSG00000239945                 0                 0                 0
#
#                  iudw_1--cluster3  iudw_1--cluster4  iudw_1--cluster5  \
# ENSG00000243485                 0                 0                 0
# ENSG00000237613                 0                 0                 0
# ENSG00000186092                 0                 0                 0
# ENSG00000238009                 0                 0                 0
# ENSG00000239945                 0                 0                 0
#
#                  iudw_1--cluster6  iudw_1--cluster7  iudw_1--cluster8  \
# ...

# %%
df.to_pickle("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/input_files/DA_all_conditions/phenotype.csv.pkl")

# %%
filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/input_files/DA_D52/phenotype.csv"

# %%
df = pd.read_csv(filename, index_col=0)
df.to_pickle("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_neuroseq/input_files/DA_D52/phenotype.csv.pkl")

# %%
filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/input_files/phenotype.csv"

# %%
df = pd.read_csv(filename, index_col=0)
df.head()
# Out:
#                           21843_1#10  21843_1#100  21843_1#101  21843_1#102  \
# ENSG00000000003_TSPAN6      5.520777     6.456208     5.878671     4.860824
# ENSG00000000419_DPM1        5.392461     6.065923     6.838769     6.614268
# ENSG00000000457_SCYL3       0.000174     0.352597     0.000000     0.825955
# ENSG00000000460_C1orf112    1.471928     4.536968     4.318528     5.373009
# ENSG00000001036_FUCA2       2.908802     3.867327     3.321747     3.736476
#
#                           21843_1#103  21843_1#105  21843_1#106  21843_1#107  \
# ENSG00000000003_TSPAN6       5.903640     4.513537     6.401983     5.909216
# ENSG00000000419_DPM1         6.512403     5.527439     6.525591     6.381135
# ENSG00000000457_SCYL3        2.201697     0.262446     0.000000     1.506837
# ENSG00000000460_C1orf112     4.636175     4.225468     0.409785     3.668277
# ENSG00000001036_FUCA2        4.917576     2.456866     0.577839     4.777404
#
# ...

# %%
df.to_pickle("/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/input_files/phenotype.csv.pkl")

# %%
# phenotype file

# %%
phenotypeFile = '/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/input_files/phenotype.csv' 
pheno = read.csv(phenotypeFile, row.names=1)
pheno[1:5,1:5]
# Out:
#                          X21843_1.10  X21843_1.100 X21843_1.101 X21843_1.102
# ENSG00000000003_TSPAN6   5.5207770563 6.4562078    5.878671     4.8608241
# ENSG00000000419_DPM1     5.3924605058 6.0659226    6.838769     6.6142685
# ENSG00000000457_SCYL3    0.0001741556 0.3525966    0.000000     0.8259555
# ENSG00000000460_C1orf112 1.4719275194 4.5369683    4.318528     5.3730090
# ENSG00000001036_FUCA2    2.9088018801 3.8673273    3.321747     3.7364760
#                          X21843_1.103
# ENSG00000000003_TSPAN6   5.903640
# ENSG00000000419_DPM1     6.512403
# ENSG00000000457_SCYL3    2.201697
# ENSG00000000460_C1orf112 4.636175
# ENSG00000001036_FUCA2    4.917576

# %%
colnames(pheno) = gsub("X","",gsub("\\.","#", colnames(pheno)))

# %%
# newrows = gsub("_.*","", rownames(pheno))
head(newrows)
rownames(pheno) = newrows
# Out:
# [1] "ENSG00000000003" "ENSG00000000419" "ENSG00000000457" "ENSG00000000460"
# [5] "ENSG00000001036" "ENSG00000001084"

# %%
pheno[1:5,1:5]
# Out:
#                 21843_1#10   21843_1#100 21843_1#101 21843_1#102 21843_1#103
# ENSG00000000003 5.5207770563 6.4562078   5.878671    4.8608241   5.903640
# ENSG00000000419 5.3924605058 6.0659226   6.838769    6.6142685   6.512403
# ENSG00000000457 0.0001741556 0.3525966   0.000000    0.8259555   2.201697
# ENSG00000000460 1.4719275194 4.5369683   4.318528    5.3730090   4.636175
# ENSG00000001036 2.9088018801 3.8673273   3.321747    3.7364760   4.917576

# %%
write.table(pheno, gsub(".csv",".tsv",phenotypeFile), sep="\t", quote=F)

# %%
# sample mapping file

# %%
sampleMappingFile = '/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/new/input_files/sample_mapping_file.csv' 
smf = read.csv(sampleMappingFile)
head(smf)
# Out:
#   genotype_individual_id phenotype_sample_id
# 1 HPSI0114i-joxm_1       21843_1#10
# 2 HPSI0314i-fafq_1       21843_1#100
# 3 HPSI0314i-fafq_1       21843_1#101
# 4 HPSI1013i-wuye_2       21843_1#102
# 5 HPSI0114i-joxm_1       21843_1#103
# 6 HPSI0114i-iisa_3       21843_1#105

# %%
write.table(smf, gsub(".csv",".tsv",sampleMappingFile), sep="\t", quote=F, row.names=F)

# %%
# make random effect term C=EEt

# %%
E_file = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/mofa_logcounts_model_factors.csv"
E = read.csv(E_file, row.names=1)
head(E)
# Out:
#             MOFA1       MOFA2    MOFA3       MOFA4     MOFA5       MOFA6
# 21843_1#10  -0.59770402 1.067436  0.05649610 1.3476606  0.64074287  0.3378262
# 21843_1#100  0.23328472 2.137884  0.64681148 1.1294599 -0.35277329 -0.0918056
# 21843_1#101 -0.05471216 1.786031 -0.09962504 0.3641184  0.05712454  0.2150318
# 21843_1#102 -0.73092365 1.132253  0.19564531 0.5882636  1.54819258  0.2512881
# 21843_1#103 -0.25739878 1.515610 -0.15481623 0.1995322  0.71918179 -0.2960872
# 21843_1#105 -0.08814416 1.718287 -0.41369690 0.1634950 -0.15204991  1.0318233
#             MOFA7      MOFA8       MOFA9      MOFA10      MOFA11     MOFA12
# 21843_1#10  -0.4664193  0.01520844 0.29224277 -0.63273743 -0.5833180  0.4731209
# 21843_1#100  0.9241371 -0.37349156 1.78959325 -0.65923266  0.4622862 -0.1388127
# 21843_1#101  0.2427277  0.07594282 0.87996128  0.68063540  0.3729296  0.2686199
# 21843_1#102 -0.3997540 -0.21080050 0.11514749  0.06005745 -0.5846824 -0.4218787
# ...

# %%
dim(E)
# Out:
# [1] 34256    20

# %%
C = as.matrix(E) %*% as.matrix(t(E))

# %%
dim(C)
# Out:
# [1] 34256 34256

# %%
C[1:5,1:5]
# Out:
#             21843_1#10 21843_1#100 21843_1#101 21843_1#102 21843_1#103
# 21843_1#10  12.366664  -3.029709   -2.318218    7.069409   4.719270
# 21843_1#100 -3.029709  23.090415   13.960737    1.501296   3.719660
# 21843_1#101 -2.318218  13.960737   12.633432    2.371352   3.117404
# 21843_1#102  7.069409   1.501296    2.371352   11.197774   6.389178
# 21843_1#103  4.719270   3.719660    3.117404    6.389178   7.340314

# %%
write.table(C, "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/debug_May2021/mofa_logcounts_model_factors_covariance.tsv", sep="\t", quote=F)

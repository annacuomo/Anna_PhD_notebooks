# %%
library(ggplot2)

# %%
## permutations when permuting G in X, and diag(g) still not in Wg
## gaussianize both E and y

# %%
filename = "/hps/nobackup/stegle/users/acuomo/all_scripts/struct_LMM2/sc_endodiff/interaction_test/MOFA/new/10mofa_factors_endo_eqtl_permuteG_inXtoo_gaussE_gaussY/summary_endo_eqtl_perms0.csv"

# %%
df = read.csv(filename, row.names=1)
df$gene = gsub("_perm0","",df$gene)
df$pv_uniform = runif(n = nrow(df), min = 0, max = 1)
# head(df)
p = ggplot(df, aes(x = sort(-log10(pv_uniform)), y = sort(-log10(pv))))
p = p + geom_point(alpha = 0.8, col = "black")
p = p + geom_abline(slope = 1) 
p
# Out:
# plot without title

# %%
hist(df$pv_raw, xlab = "permuted p values", main = paste0("median = ", round(median(df$pv_raw), digits = 2)))
# median(df$pv_raw)
# Out:
# Plot with title “median = 0.01”

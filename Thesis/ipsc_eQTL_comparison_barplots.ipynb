# %%
options(repr.plot.width = 7, repr.plot.height = 5)

# y1-values
peptide_total <- c(1833, 2908, 1356, 896, 634)
# y2-values
peptide_unique <- c(1283, 1577, 1032, 759, 567)

col_bulk = "slategray3"
# col_sc = "steelblue4"
col_sc = "peachpuff3"

# determine ymax (from y1-values)
ymax <- peptide_total[which.max(peptide_total)]

opar <- par(lwd = 2)

# assign vector of midpoint-values of first barplot (y1) to x 
x <- barplot(peptide_total, border = c(col_sc, col_bulk, col_bulk, col_bulk, col_bulk), 
             col = 'white', xlim = c(0, 6), ylim = c(0, 3000), space = 0.8,
             width = 0.5, ylab = "# eGenes")

par(new = TRUE)

barplot(peptide_unique,  border = c(col_bulk, col_sc, col_sc, col_sc, col_sc), 
        col = c(col_bulk, col_sc, col_sc, col_sc, col_sc),
        xlim = c(-0.2, 5.8), ylim = c(0, 3000),
        width = 0.5, space = 0.8, axisnames = FALSE)
# Out:
# plot without title

# %%
options(repr.plot.width = 7, repr.plot.height = 5)

# y1-values
peptide_total <- c(2452, 1179, 775, 543)
# y2-values
peptide_unique <- c(1069, 704, 538, 416)
# y3-values
peptide_unique2 <- c(1044, 660, 486, 372)

col_bulk = "slategray3"
col_sc = "peachpuff3"
col_sc_10x = "indianred4"

# determine ymax (from y1-values)
ymax <- peptide_total[which.max(peptide_total)]

opar <- par(lwd = 2)

# assign vector of midpoint-values of first barplot (y1) to x 
x <- barplot(peptide_total, border = c(col_bulk, col_bulk, col_bulk, col_bulk), 
             col = 'white', xlim = c(0, 6), ylim = c(0, 3000), space = 1.4,
             width = 0.4, ylab = "# eGenes")

par(new = TRUE)

barplot(peptide_unique,  border = c(col_sc, col_sc, col_sc, col_sc), 
        col = c(col_sc, col_sc, col_sc, col_sc),
        xlim = c(-0.2, 5.8), ylim = c(0, 3000),
        width = 0.4, space = 1.4, axisnames = FALSE)

par(new = TRUE)

barplot(peptide_unique2,  border = c(col_sc_10x, col_sc_10x, col_sc_10x, col_sc_10x), 
        col = c(col_sc_10x, col_sc_10x, col_sc_10x, col_sc_10x),
        xlim = c(-0.4, 5.6), ylim = c(0, 3000),
        width = 0.4, space = 1.4, axisnames = FALSE)
# Out:
# plot without title
